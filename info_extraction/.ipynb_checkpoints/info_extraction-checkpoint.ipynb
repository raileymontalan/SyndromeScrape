# %%
import nltk
import numpy as np
import pandas as pd

# %%
def preprocess(doc):
    # Sentence segmenter
    sentences = nltk.sent_tokenize(doc)
    # Word tokenizer
    sentences = [nltk.word_tokenize(sent) for sent in sentences]
    # Parts of speech tagger
    sentences = [nltk.pos_tag(sent) for sent in sentences]
    
    return sentences

# %%
def NPchunking(sentence):
    # Naive chunking 
    grammar = "NP: {<[CDJNP].*>+}"
    cp = nltk.RegexpParser(grammar)
    print(cp.parse(sentence))

# %%
def Regexchunking(sentence):
    # Naive chunking 
    grammar = r"""
        CHUNK:  {<DT|PP\$>?<JJ>*<NN>}   # chunk determiner/possessive, adjectives and noun
                {<NNP>+}                # chunk sequences of proper nouns
    """
    cp = nltk.RegexpParser(grammar)
    print(cp.parse(sentence))

# %%
df = pd.read_json('infodem_docs.json', encoding='utf-8')
for doc in df['content']:
    sentences = preprocess(doc)
    for sentence in sentences:
        Regexchunking(sentence)
# Out:
# (S
#   (CHUNK ISABELA/NNP)
#   ,/,
#   (CHUNK Philippines/NNP)
#   –/VBZ
#   (CHUNK The/DT rainy/NN)
#   (CHUNK season/NN)
#   has/VBZ
#   just/RB
#   started/VBN
#   ,/,
#   but/CC
#   (CHUNK the/DT municipality/NN)
#   of/IN
#   (CHUNK Luna/NNP)
#   in/IN
#   (CHUNK Isabela/NNP)
#   (CHUNK province/NN)
#   in/IN
#   the/DT
#   northern/JJ
#   Philippines/NNPS
#   already/RB
#   declared/VBD
#   (CHUNK state/NN)
#   of/IN
#   (CHUNK calamity/NN)
#   after/IN
#   their/PRP$
#   (CHUNK health/NN)
#   (CHUNK office/NN)
#   recorded/VBD
#   54/CD
#   cases/NNS
#   of/IN
#   (CHUNK dengue/NN)
#   in/IN
#   just/RB
#   (CHUNK the/DT month/NN)
#   of/IN
#   (CHUNK June/NNP)
#   ./.)
# (S
#   (CHUNK Dengue/NNP)
#   is/VBZ
#   (CHUNK a/DT fever/NN)
#   ,/,
#   usually/RB
#   fatal/JJ
#   ,/,
#   caused/VBN
#   by/IN
#   (CHUNK a/DT bite/NN)
#   of/IN
#   (CHUNK Aedes/NNP)
#   (CHUNK mosquito/NN)
#   ./.)
# (S
#   It/PRP
#   targets/VBZ
#   (CHUNK the/DT immune/JJ system/NN)
#   of/IN
#   (CHUNK the/DT body/NN)
#   ./.)
# (S
#   (CHUNK Dr/NNP Claire/NNP Francisco/NNP)
#   ,/,
#   (CHUNK Luna/NNP ’/NNP)
#   s/VBZ
#   (CHUNK health/NN)
#   (CHUNK officer/NN)
#   ,/,
#   said/VBD
#   on/IN
#   (CHUNK Tuesday/NNP)
#   ,/,
#   (CHUNK June/NNP)
#   30/CD
#   ,/,
#   (CHUNK the/DT number/NN)
#   of/IN
#   cases/NNS
#   reported/VBN
#   for/IN
#   (CHUNK the/DT month/NN)
#   is/VBZ
#   “/RBR
#   significantly/RB
#   ''/''
#   higher/JJR
#   compared/VBN
#   to/TO
#   the/DT
#   numbers/NNS
#   reported/VBN
#   in/IN
#   (CHUNK the/DT same/JJ month/NN)
#   in/IN
#   previous/JJ
#   years/NNS
#   ./.)
# (S
#   Although/IN
#   there/EX
#   is/VBZ
#   (CHUNK no/DT case/NN)
#   of/IN
#   (CHUNK death/NN)
#   from/IN
#   (CHUNK dengue/NN)
#   yet/RB
#   ,/,
#   (CHUNK the/DT increase/NN)
#   in/IN
#   the/DT
#   reported/JJ
#   cases/NNS
#   of/IN
#   (CHUNK the/DT disease/NN)
#   prompted/VBD
#   (CHUNK the/DT local/JJ government/NN)
#   (CHUNK unit/NN)
#   to/TO
#   declare/VB
#   (CHUNK a/DT state/NN)
#   of/IN
#   (CHUNK calamity/NN)
#   to/TO
#   be/VB
#   able/JJ
#   to/TO
#   release/VB
#   funds/NNS
#   for/IN
#   (CHUNK the/DT purchase/NN)
#   of/IN
#   (CHUNK medical/JJ equipment/NN)
#   ./.)
# (S
#   (CHUNK Francisco/NNP)
#   said/VBD
#   (CHUNK the/DT purchase/NN)
#   of/IN
#   (CHUNK equipment/NN)
#   will/MD
#   also/RB
#   be/VB
#   (CHUNK anticipation/NN)
#   of/IN
#   more/JJR
#   cases/NNS
#   during/IN
#   (CHUNK the/DT rainy/NN)
#   (CHUNK season/NN)
#   ./.)
# (S
#   (CHUNK Thirteen/NNP)
#   out/IN
#   of/IN
#   19/CD
#   barangays/NNS
#   (/(
#   villages/NNS
#   )/)
#   in/IN
#   (CHUNK the/DT town/NN)
#   were/VBD
#   affected/VBN
#   ,/,
#   she/PRP
#   said/VBD
#   ./.)
# (S
#   (CHUNK Francisco/NNP)
#   advised/VBD
#   residents/NNS
#   to/TO
#   maintain/VB
#   (CHUNK cleanliness/NN)
#   and/CC
#   get/VB
#   rid/JJ
#   of/IN
#   stagnant/JJ
#   waters/NNS
#   so/RB
#   dengue-causing/JJ
#   mosquitoes/NNS
#   would/MD
#   not/RB
#   have/VB
#   places/NNS
#   to/TO
#   breed/VB
#   in/IN
#   ./.)
# (S
#   Rising/VBG
#   cases/NNS
#   In/IN
#   (CHUNK April/NNP)
#   ,/,
#   the/DT
#   (CHUNK Department/NNP)
#   of/IN
#   (CHUNK Health/NNP)
#   (/(
#   (CHUNK DOH/NNP)
#   )/)
#   reported/VBD
#   6.49/CD
#   (CHUNK %/NN)
#   (CHUNK increase/NN)
#   of/IN
#   dengue/JJ
#   cases/NNS
#   in/IN
#   (CHUNK the/DT country/NN)
#   ,/,
#   citing/VBG
#   19,946/CD
#   cases/NNS
#   in/IN
#   (CHUNK the/DT first/JJ quarter/NN)
#   of/IN
#   2015/CD
#   ./.)
# (S
#   (CHUNK The/DT number/NN)
#   reached/VBD
#   744/CD
#   in/IN
#   (CHUNK Cagayan/NNP Valley/NNP)
#   ,/,
#   while/IN
#   (CHUNK Calabarzon/NNP)
#   had/VBD
#   the/DT
#   highest/JJS
#   with/IN
#   3,778/CD
#   and/CC
#   the/DT
#   Autonomous/JJ
#   (CHUNK Region/NNP)
#   of/IN
#   (CHUNK Muslim/NNP Mindanao/NNP)
#   (/(
#   (CHUNK ARMM/NNP)
#   )/)
#   had/VBD
#   the/DT
#   lowest/JJS
#   with/IN
#   312/CD
#   ./.)
# (S
#   (CHUNK Philhealth/NNP)
#   subsidizes/VBZ
#   (CHUNK dengue/JJ case/NN)
#   (CHUNK confinement/NN)
#   with/IN
#   to/TO
#   (CHUNK P31,300/NNP)
#   for/IN
#   (CHUNK level/NN)
#   3/CD
#   ./.)
# (S
#   (CHUNK The/DT subsidy/NN)
#   covers/VBZ
#   (CHUNK the/DT maximum/JJ allowable/JJ expense/NN)
#   for/IN
#   (CHUNK room/NN)
#   ,/,
#   drugs/NNS
#   and/CC
#   medicines/NNS
#   ,/,
#   and/CC
#   (CHUNK laboratory/NN)
#   tests/NNS
#   ./.)
# (S
#   (CHUNK The/DT health/NN)
#   (CHUNK department/NN)
#   is/VBZ
#   expecting/VBG
#   (CHUNK the/DT number/NN)
#   of/IN
#   dengue/JJ
#   cases/NNS
#   to/TO
#   peak/VB
#   in/IN
#   the/DT
#   months/NNS
#   of/IN
#   (CHUNK July/NNP)
#   and/CC
#   (CHUNK August/NNP)
#   ./.)
# (S
#   (CHUNK ILOILO/NNP)
#   ,/,
#   (CHUNK Philippines/NNP)
#   –/VBZ
#   (CHUNK The/DT number/NN)
#   of/IN
#   (CHUNK dengue/NN)
#   cases/NNS
#   has/VBZ
#   surged/VBD
#   in/IN
#   this/DT
#   Western/JJ
#   (CHUNK Visayas/NNP)
#   (CHUNK province/NN)
#   ,/,
#   infecting/VBG
#   more/JJR
#   than/IN
#   1,800/CD
#   people/NNS
#   and/CC
#   killing/VBG
#   at/IN
#   least/JJS
#   10/CD
#   ,/,
#   (CHUNK a/DT provincial/JJ official/NN)
#   said/VBD
#   (CHUNK Saturday/NNP)
#   ,/,
#   (CHUNK July/NNP)
#   6/CD
#   ./.)
# (S
#   (CHUNK The/DT number/NN)
#   of/IN
#   people/NNS
#   struck/VBP
#   down/RP
#   by/IN
#   (CHUNK the/DT mosquito-borne/JJ disease/NN)
#   in/IN
#   (CHUNK Iloilo/NNP)
#   (CHUNK this/DT year/NN)
#   is/VBZ
#   already/RB
#   71/CD
#   (CHUNK %/NN)
#   higher/JJR
#   than/IN
#   (CHUNK the/DT same/JJ period/NN)
#   (CHUNK last/JJ year/NN)
#   ,/,
#   (CHUNK provincial/JJ administrator/NN)
#   (CHUNK Raul/NNP Banias/NNP)
#   told/VBD
#   (CHUNK Agence/NNP France-Presse/NNP)
#   ./.)
# (S
#   He/PRP
#   added/VBD
#   (CHUNK dengue/NN)
#   fatalities/NNS
#   in/IN
#   (CHUNK the/DT first/JJ half/NN)
#   of/IN
#   2013/CD
#   were/VBD
#   already/RB
#   equal/JJ
#   to/TO
#   the/DT
#   total/JJ
#   deaths/NNS
#   for/IN
#   (CHUNK the/DT whole/NN)
#   of/IN
#   2012/CD
#   ./.)
# (S
#   The/DT
#   latest/JJS
#   (CHUNK outbreak/NN)
#   in/IN
#   (CHUNK the/DT province/NN)
#   ,/,
#   located/VBN
#   around/IN
#   400/CD
#   kilometers/NNS
#   south/RB
#   of/IN
#   (CHUNK Manila/NNP)
#   ,/,
#   has/VBZ
#   caused/VBN
#   (CHUNK particular/JJ alarm/NN)
#   ,/,
#   because/IN
#   it/PRP
#   began/VBD
#   before/IN
#   (CHUNK the/DT start/NN)
#   of/IN
#   (CHUNK rainy/NN)
#   (CHUNK season/NN)
#   in/IN
#   (CHUNK June/NNP)
#   ,/,
#   when/WRB
#   mosquitoes/NNS
#   are/VBP
#   less/RBR
#   plentiful/JJ
#   ,/,
#   he/PRP
#   said/VBD
#   ./.)
# (S
#   He/PRP
#   added/VBD
#   that/IN
#   (CHUNK the/DT outbreak/NN)
#   may/MD
#   be/VB
#   (CHUNK a/DT sign/NN)
#   of/IN
#   the/DT
#   changing/VBG
#   (CHUNK behavior/NN)
#   of/IN
#   mosquitoes/NNS
#   and/CC
#   (CHUNK a/DT result/NN)
#   of/IN
#   people/NNS
#   storing/VBG
#   (CHUNK water/NN)
#   improperly/RB
#   ./.)
# (S
#   (CHUNK Dengue/NNP)
#   is/VBZ
#   spread/VBN
#   by/IN
#   mosquitoes/NNS
#   that/WDT
#   breed/VBP
#   in/IN
#   (CHUNK stagnant/JJ water/NN)
#   and/CC
#   usually/RB
#   bite/JJ
#   people/NNS
#   during/IN
#   (CHUNK daytime/NN)
#   ./.)
# (S
#   ``/``
#   But/CC
#   (CHUNK the/DT behavior/NN)
#   of/IN
#   the/DT
#   mosquitoes/NNS
#   has/VBZ
#   changed/VBN
#   ./.)
# (S
#   They/PRP
#   are/VBP
#   no/RB
#   longer/RB
#   biting/VBG
#   only/RB
#   during/IN
#   (CHUNK the/DT day/NN)
#   ./.)
# (S
#   Even/RB
#   at/IN
#   (CHUNK night/NN)
#   ,/,
#   they/PRP
#   are/VBP
#   biting/VBG
#   ,/,
#   ''/''
#   he/PRP
#   said/VBD
#   ./.)
# (S
#   Additionally/RB
#   ,/,
#   many/JJ
#   of/IN
#   the/DT
#   1.6/CD
#   million/CD
#   people/NNS
#   living/VBG
#   in/IN
#   (CHUNK the/DT largely-rural/JJ province/NN)
#   still/RB
#   (CHUNK stockpile/JJ water/NN)
#   in/IN
#   their/PRP$
#   homes/NNS
#   due/JJ
#   to/TO
#   lack/VB
#   of/IN
#   (CHUNK proper/JJ plumbing/NN)
#   ,/,
#   making/VBG
#   it/PRP
#   easier/JJR
#   for/IN
#   the/DT
#   mosquitoes/NNS
#   to/TO
#   breed/VB
#   ./.)
# (S
#   (CHUNK Provincial/NNP)
#   (CHUNK health/NN)
#   workers/NNS
#   are/VBP
#   now/RB
#   being/VBG
#   deployed/VBN
#   to/TO
#   the/DT
#   hardest-hit/JJ
#   areas/NNS
#   to/TO
#   inspect/VB
#   homes/NNS
#   ,/,
#   searching/VBG
#   for/IN
#   (CHUNK any/DT water/NN)
#   (CHUNK container/NN)
#   where/WRB
#   the/DT
#   mosquitoes/NNS
#   might/MD
#   breed/VB
#   ,/,
#   (CHUNK Banias/NNP)
#   said/VBD
#   ./.)
# (S
#   Residents/NNS
#   are/VBP
#   also/RB
#   being/VBG
#   advised/VBN
#   to/TO
#   keep/VB
#   their/PRP$
#   (CHUNK water/NN)
#   containers/NNS
#   covered/VBD
#   while/IN
#   victims/NNS
#   are/VBP
#   being/VBG
#   given/VBN
#   (CHUNK free/JJ treatment/NN)
#   in/IN
#   (CHUNK government/NN)
#   hospitals/NNS
#   ,/,
#   he/PRP
#   said/VBD
#   ./.)
# (S
#   (CHUNK Dengue/NNP)
#   (CHUNK fever/NN)
#   is/VBZ
#   a/DT
#   recurring/VBG
#   (CHUNK problem/NN)
#   in/IN
#   the/DT
#   Philippines/NNPS
#   ./.)
# (S
#   While/IN
#   (CHUNK the/DT number/NN)
#   of/IN
#   incidents/NNS
#   (CHUNK this/DT year/NN)
#   is/VBZ
#   slightly/RB
#   lower/JJR
#   (CHUNK nationwide/NN)
#   ,/,
#   it/PRP
#   has/VBZ
#   been/VBN
#   spiking/VBG
#   in/IN
#   certain/JJ
#   areas/NNS
#   such/JJ
#   as/IN
#   (CHUNK Iloilo/NNP)
#   ./.)
# (S
#   (CHUNK MANILA/NNP)
#   ,/,
#   (CHUNK Philippines/NNP –/NNP)
#   While/IN
#   (CHUNK the/DT number/NN)
#   of/IN
#   dengue/JJ
#   cases/NNS
#   in/IN
#   (CHUNK the/DT country/NN)
#   decreased/VBD
#   over/IN
#   (CHUNK the/DT year/NN)
#   ,/,
#   (CHUNK Visayas/NNP)
#   and/CC
#   (CHUNK Mindanao/NNP)
#   are/VBP
#   (CHUNK the/DT exception/NN)
#   to/TO
#   (CHUNK the/DT overall/JJ trend/NN)
#   ./.)
# (S
#   The/DT
#   (CHUNK Department/NNP)
#   of/IN
#   (CHUNK Health/NNP)
#   (/(
#   (CHUNK DOH/NNP)
#   )/)
#   on/IN
#   (CHUNK Wednesday/NNP)
#   ,/,
#   (CHUNK July/NNP)
#   31/CD
#   ,/,
#   reported/VBD
#   a/DT
#   7.7/CD
#   (CHUNK %/NN)
#   (CHUNK drop/NN)
#   in/IN
#   the/DT
#   cases/NNS
#   of/IN
#   (CHUNK dengue/NN)
#   from/IN
#   67,339/CD
#   in/IN
#   (CHUNK July/NNP)
#   2012/CD
#   to/TO
#   62,156/CD
#   (CHUNK today/NN)
#   ./.)
# (S
#   (CHUNK DOH/NNP Secretary/NNP Enrique/NNP Ona/NNP)
#   noted/VBD
#   (CHUNK the/DT significant/JJ decline/NN)
#   of/IN
#   (CHUNK dengue/NN)
#   cases/NNS
#   in/IN
#   (CHUNK Luzon/NNP)
#   ./.)
# (S
#   In/IN
#   the/DT
#   (CHUNK National/NNP Capital/NNP Region/NNP)
#   ,/,
#   cases/NNS
#   of/IN
#   (CHUNK the/DT infectious/JJ disease/NN)
#   went/VBD
#   down/RB
#   by/IN
#   69/CD
#   (CHUNK %/NN)
#   based/VBN
#   on/IN
#   (CHUNK DOH/NNP)
#   data/NNS
#   ./.)
# (S
#   (CHUNK The/DT region/NN)
#   recorded/VBD
#   the/DT
#   highest/JJS
#   (CHUNK decline/NN)
#   in/IN
#   (CHUNK the/DT entire/JJ country/NN)
#   ./.)
# (S
#   The/DT
#   (CHUNK Visayas/NNP)
#   and/CC
#   (CHUNK Mindanao/NNP)
#   ,/,
#   however/RB
#   ,/,
#   reported/VBD
#   (CHUNK a/DT surge/NN)
#   of/IN
#   (CHUNK dengue/NN)
#   cases/NNS
#   ./.)
# (S
#   (CHUNK The/DT uptick/NN)
#   was/VBD
#   pegged/VBN
#   at/IN
#   53/CD
#   (CHUNK %/NN)
#   in/IN
#   (CHUNK Visayas/NNP)
#   and/CC
#   44/CD
#   (CHUNK %/NN)
#   in/IN
#   (CHUNK Mindanao/NNP)
#   ./.)
# (S
#   The/DT
#   (CHUNK DOH/NNP)
#   said/VBD
#   (CHUNK the/DT alarming/NN)
#   figures/NNS
#   outside/IN
#   of/IN
#   (CHUNK Luzon/NNP)
#   can/MD
#   be/VB
#   due/JJ
#   to/TO
#   “/VB
#   higher/JJR
#   amounts/NNS
#   of/IN
#   (CHUNK precipitation/NN)
#   (CHUNK ”/NN)
#   experienced/VBD
#   in/IN
#   those/DT
#   areas/NNS
#   during/IN
#   (CHUNK the/DT first/JJ half/NN)
#   of/IN
#   (CHUNK the/DT year/NN)
#   ./.)
# (S
#   (CHUNK Last/JJ year/NN)
#   ,/,
#   (CHUNK Mindanao/NNP ’/NNP)
#   s/VBD
#   (CHUNK Davao/NNP City/NNP)
#   registered/VBD
#   a/DT
#   300/CD
#   (CHUNK %/NN)
#   (CHUNK increase/NN)
#   in/IN
#   the/DT
#   cases/NNS
#   of/IN
#   (CHUNK dengue/NN)
#   (CHUNK fever/NN)
#   ./.)
# (S
#   On/IN
#   (CHUNK July/NNP)
#   6/CD
#   ,/,
#   (CHUNK Iloilo/NNP)
#   (CHUNK province/NN)
#   of/IN
#   Western/JJ
#   (CHUNK Visayas/NNP)
#   also/RB
#   reported/VBD
#   a/DT
#   71/CD
#   (CHUNK %/NN)
#   (CHUNK surge/NN)
#   ./.)
# (S
#   (CHUNK Dengue/NNP)
#   is/VBZ
#   (CHUNK a/DT mosquito-borne/JJ disease/NN)
#   frequently/RB
#   occurring/VBG
#   in/IN
#   tropical/JJ
#   and/CC
#   sub-tropical/JJ
#   regions/NNS
#   that/WDT
#   may/MD
#   lead/VB
#   to/TO
#   lethal/JJ
#   complications/NNS
#   ./.)
# (S
#   (CHUNK Loss/NNP)
#   of/IN
#   lives/NNS
#   (CHUNK Emily/NNP Divinagracia/NNP)
#   lost/VBD
#   her/PRP$
#   (CHUNK brother/NN)
#   to/TO
#   dengue/VB
#   in/IN
#   the/DT
#   1980s/CD
#   ./.)
# (S
#   ``/``
#   What/WP
#   it/PRP
#   did/VBD
#   was/VBD
#   bring/VB
#   (CHUNK home/NN)
#   (CHUNK the/DT fact/NN)
#   that/IN
#   (CHUNK those/DT abstract/JJ morbidity/NN)
#   and/CC
#   (CHUNK mortality/NN)
#   figures…/NNS
#   are/VBP
#   n't/RB
#   abstract/JJ
#   at/IN
#   all—that/IN
#   these/DT
#   are/VBP
#   real/JJ
#   people/NNS
#   ,/,
#   leading/VBG
#   real/JJ
#   lives/NNS
#   ,/,
#   whose/WP$
#   illnesses/NNS
#   affect/VBP
#   real/JJ
#   families/NNS
#   ,/,
#   ''/''
#   she/PRP
#   said/VBD
#   ./.)
# (S
#   In/IN
#   an/DT
#   e-mail/JJ
#   to/TO
#   (CHUNK Rappler/NNP)
#   ,/,
#   (CHUNK Divinagracia/NNP)
#   recalled/VBD
#   her/PRP$
#   (CHUNK brother/NN)
#   (CHUNK ’/NN)
#   s/VBD
#   (CHUNK sudden/JJ demise/NN)
#   at/IN
#   (CHUNK the/DT age/NN)
#   of/IN
#   27/CD
#   ./.)
# (S
#   ``/``
#   After/IN
#   graduating/VBG
#   from/IN
#   (CHUNK UP/NNP Law/NNP)
#   as/IN
#   (CHUNK the/DT president/NN)
#   of/IN
#   his/PRP$
#   (CHUNK class/NN)
#   ,/,
#   passing/VBG
#   (CHUNK the/DT bar/NN)
#   (CHUNK exams/NN)
#   in/IN
#   the/DT
#   top/JJ
#   20/CD
#   ,/,
#   and/CC
#   working/VBG
#   at/IN
#   the/DT
#   (CHUNK Supreme/NNP Court/NNP)
#   under/IN
#   then-Justice/JJ
#   (CHUNK Irene/NNP Cortes/NNP)
#   ,/,
#   my/PRP$
#   (CHUNK brother/NN)
#   (CHUNK John/NNP)
#   caught/VBD
#   (CHUNK dengue/NN)
#   (CHUNK fever/NN)
#   and/CC
#   passed/VBD
#   away/RB
#   from/IN
#   (CHUNK dengue/JJ hemorrhagic/NN)
#   (CHUNK shock/NN)
#   after/IN
#   5/CD
#   days/NNS
#   in/IN
#   (CHUNK hospital/NN)
#   ,/,
#   ''/''
#   she/PRP
#   narrated/VBD
#   ./.)
# (S
#   (CHUNK Divinagracia/NNP)
#   herself/PRP
#   took/VBD
#   up/RP
#   (CHUNK medicine/NN)
#   at/IN
#   the/DT
#   (CHUNK University/NNP)
#   of/IN
#   the/DT
#   Philippines/NNPS
#   (/(
#   (CHUNK UP/NNP)
#   )/)
#   (CHUNK Manila/NNP)
#   ./.)
# (S
#   She/PRP
#   said/VBD
#   (CHUNK the/DT virus-carrying/NN)
#   mosquitoes/NNS
#   could/MD
#   have/VB
#   come/VBN
#   from/IN
#   (CHUNK anywhere–/NN)
#   ''/''
#   (CHUNK water/NN)
#   in/IN
#   pails/NNS
#   ,/,
#   improperly-covered/JJ
#   containers/NNS
#   ,/,
#   long/RB
#   stagnant/JJ
#   puddles/NNS
#   because/IN
#   of/IN
#   (CHUNK rain/NN)
#   ,/,
#   coupled/VBN
#   with/IN
#   (CHUNK poor/JJ drainage/NN)
#   ./.
#   ''/'')
# (S
#   (CHUNK New/NNP)
#   (CHUNK treatment/NN)
#   guidelines/NNS
#   (CHUNK This/DT year/NN)
#   ,/,
#   (CHUNK dengue/NN)
#   fatalities/NNS
#   dropped/VBD
#   to/TO
#   263/CD
#   cases/NNS
#   ./.)
# (S
#   (CHUNK The/DT death/NN)
#   (CHUNK toll/NN)
#   is/VBZ
#   40/CD
#   (CHUNK %/NN)
#   lower/JJR
#   than/IN
#   (CHUNK last/JJ year/NN)
#   ’/VBD
#   s/JJ
#   435/CD
#   during/IN
#   (CHUNK this/DT same/JJ period/NN)
#   ./.)
# (S
#   The/DT
#   (CHUNK DOH/NNP)
#   said/VBD
#   (CHUNK new/JJ treatment/NN)
#   guidelines/NNS
#   now/RB
#   focus/VBP
#   on/IN
#   earlier/JJR
#   (CHUNK replenishment/NN)
#   of/IN
#   (CHUNK body/NN)
#   fluids/NNS
#   ./.)
# (S
#   (CHUNK The/DT health/NN)
#   (CHUNK agency/NN)
#   issues/NNS
#   and/CC
#   updates/VBZ
#   clinical/JJ
#   pathways/NNS
#   –/VBP
#   (CHUNK a/DT standardized/JJ management/NN)
#   of/IN
#   diseases/NNS
#   (CHUNK –/NNP)
#   disseminated/VBD
#   to/TO
#   doctors/NNS
#   in/IN
#   public/JJ
#   hospitals/NNS
#   across/IN
#   (CHUNK the/DT county/NN)
#   ./.)
# (S
#   (CHUNK Divinagracia/NNP)
#   who/WP
#   experienced/VBD
#   (CHUNK the/DT impact/NN)
#   of/IN
#   (CHUNK the/DT disease/NN)
#   (CHUNK first-hand/JJ –/NN)
#   during/IN
#   her/PRP$
#   (CHUNK brother/NN)
#   (CHUNK ’/NN)
#   (CHUNK s/JJ death/NN)
#   in/IN
#   the/DT
#   80s/CD
#   and/CC
#   when/WRB
#   she/PRP
#   was/VBD
#   diagnosed/VBN
#   with/IN
#   (CHUNK dengue/NN)
#   in/IN
#   1997/CD
#   (CHUNK –/NN)
#   said/VBD
#   (CHUNK early/JJ detection/NN)
#   would/MD
#   help/VB
#   (CHUNK Filipino/NNP)
#   families/NNS
#   ./.)
# (S
#   ``/``
#   (CHUNK The/DT sort/NN)
#   of/IN
#   rapid/JJ
#   screening/VBG
#   tests/NNS
#   (CHUNK available/JJ today/NN)
#   were/VBD
#   n't/RB
#   available/JJ
#   24/CD
#   years/NNS
#   ago/RB
#   ,/,
#   which/WDT
#   means/VBZ
#   (CHUNK supportive/JJ therapy/NN)
#   can/MD
#   be/VB
#   started/VBN
#   much/RB
#   earlier/JJR
#   than/IN
#   before/RB
#   ,/,
#   ''/''
#   she/PRP
#   said/VBD
#   ./.)
# (S
#   (CHUNK Chikungunya/NNP)
#   outbreak/PRP
#   Meanwhile/RB
#   ,/,
#   (CHUNK Ona/NNP)
#   said/VBD
#   on/IN
#   (CHUNK Wednesday/NNP)
#   ,/,
#   (CHUNK July/NNP)
#   31/CD
#   ,/,
#   that/IN
#   it/PRP
#   was/VBD
#   only/RB
#   (CHUNK a/DT matter/NN)
#   of/IN
#   (CHUNK time/NN)
#   before/IN
#   the/DT
#   (CHUNK Chikungunya/NNP)
#   (CHUNK virus/NN)
#   hit/VBD
#   the/DT
#   Philippines/NNPS
#   ./.)
# (S
#   (CHUNK A/DT surge/NN)
#   of/IN
#   cases/NNS
#   ,/,
#   he/PRP
#   said/VBD
#   ,/,
#   had/VBD
#   already/RB
#   been/VBN
#   reported/VBN
#   in/IN
#   (CHUNK Thailand/NNP)
#   and/CC
#   (CHUNK Singapore/NNP)
#   (CHUNK last/JJ year/NN)
#   ./.)
# (S
#   ``/``
#   (CHUNK Chikungkunya/NNP)
#   is/VBZ
#   (CHUNK a/DT viral/JJ disease/NN)
#   similar/JJ
#   to/TO
#   dengue/VB
#   ,/,
#   ''/''
#   (CHUNK the/DT health/NN)
#   (CHUNK secretary/NN)
#   said/VBD
#   ./.)
# (S
#   ``/``
#   (CHUNK Less/NNP)
#   (CHUNK ang/JJ chance/NN)
#   of/IN
#   dying/VBG
#   ./.)
# (S
#   However/RB
#   ,/,
#   (CHUNK mas/JJ matagal/NN)
#   (CHUNK ang/JJ side/NN)
#   effects/NNS
#   (/(
#   (CHUNK The/DT chance/NN)
#   of/IN
#   dying/VBG
#   is/VBZ
#   less/RBR
#   ./.)
# (S
#   However/RB
#   ,/,
#   (CHUNK the/DT side/NN)
#   effects/NNS
#   last/JJ
#   longer/JJR
#   )/)
#   ./.
#   ''/'')
# (S
#   The/DT
#   (CHUNK Philippine/NNP Star/NNP)
#   reported/VBD
#   (CHUNK an/DT outbreak/NN)
#   of/IN
#   (CHUNK the/DT disease/NN)
#   in/IN
#   10/CD
#   Philippine/JJ
#   municipalities/NNS
#   ./.)
# (S
#   (CHUNK The/DT health/NN)
#   (CHUNK chief/NN)
#   added/VBD
#   that/IN
#   (CHUNK sore/NN)
#   muscles/NNS
#   are/VBP
#   often/RB
#   experienced/VBN
#   even/RB
#   after/IN
#   one/CD
#   is/VBZ
#   healed/VBN
#   ./.)
# (S
#   ``/``
#   It/PRP
#   is/VBZ
#   even/RB
#   difficult/JJ
#   to/TO
#   differentiate/VB
#   it/PRP
#   from/IN
#   (CHUNK an/DT ordinary/JJ flu/NN)
#   ,/,
#   except/IN
#   mas/FW
#   (CHUNK matindi/NN)
#   (CHUNK ang/NN)
#   (/(
#   there/EX
#   is/VBZ
#   worse/JJR
#   )/)
#   (CHUNK muscle/NN)
#   and/CC
#   (CHUNK joint/JJ pain/NN)
#   ,/,
#   ''/''
#   he/PRP
#   explained/VBD
#   ./.)
# (S
#   (CHUNK DOH/NNP)
#   efforts/NNS
#   (CHUNK Ona/NNP)
#   encouraged/VBD
#   local/JJ
#   governments/NNS
#   to/TO
#   step/VB
#   up/RP
#   their/PRP$
#   anti-dengue/JJ
#   campaigns/NNS
#   as/IN
#   more/RBR
#   frequent/JJ
#   rains/NNS
#   will/MD
#   ''/''
#   “/VB
#   (CHUNK herald/NN)
#   increased/VBN
#   (CHUNK mosquito/JJ population/NN)
#   that/WDT
#   thrive/VBP
#   in/IN
#   (CHUNK stagnant/JJ water/NN)
#   ./.
#   ''/'')
# (S
#   The/DT
#   (CHUNK DOH/NNP)
#   is/VBZ
#   currently/RB
#   monitoring/VBG
#   the/DT
#   (CHUNK Ovicidal-Larvicidal/NNP)
#   (/(
#   (CHUNK OL/NNP)
#   )/)
#   (CHUNK mosquito/NN)
#   traps/NNS
#   –/VBP
#   (CHUNK an/DT innovation/NN)
#   introduced/VBN
#   through/IN
#   (CHUNK a/DT joint/JJ project/NN)
#   with/IN
#   (CHUNK other/JJ government/NN)
#   agencies/NNS
#   –/VBP
#   placed/VBN
#   in/IN
#   schools/NNS
#   and/CC
#   communities/NNS
#   ./.)
# (S
#   (/(
#   READ/VB
#   :/:
#   (CHUNK Crowdsourcing/NNP)
#   (CHUNK dengue/NN)
#   (CHUNK alert/NN)
#   )/)
#   (CHUNK A/DT habit/NN)
#   of/IN
#   searching/VBG
#   for/IN
#   and/CC
#   eliminating/VBG
#   mosquito-breeding/JJ
#   sites/NNS
#   in/IN
#   local/JJ
#   communities/NNS
#   at/IN
#   least/JJS
#   once/RB
#   (CHUNK a/DT week/NN)
#   was/VBD
#   also/RB
#   launched/VBN
#   by/IN
#   the/DT
#   (CHUNK DOH/NNP)
#   ./.)
# (S
#   (CHUNK The/DT strategy/NN)
#   needs/VBZ
#   (CHUNK collective/JJ community/NN)
#   efforts/NNS
#   ,/,
#   with/IN
#   the/DT
#   searches/NNS
#   routinely/RB
#   done/VBN
#   4/CD
#   (CHUNK pm/NN)
#   onwards/NNS
#   ./.)
# (S
#   (CHUNK MANILA/NNP)
#   ,/,
#   (CHUNK Philippines/NNP –/NNP)
#   Can/MD
#   the/DT
#   Philippines/NNPS
#   (CHUNK eliminate/NN)
#   measles/NNS
#   in/IN
#   3/CD
#   years/NNS
#   '/POS
#   (CHUNK time/NN)
#   ?/.)
# (S
#   The/DT
#   (CHUNK Department/NNP)
#   of/IN
#   (CHUNK Health/NNP)
#   (/(
#   (CHUNK DOH/NNP)
#   )/)
#   said/VBD
#   there/EX
#   is/VBZ
#   (CHUNK enough/JJ time/NN)
#   as/IN
#   it/PRP
#   prepares/VBZ
#   for/IN
#   (CHUNK a/DT nationwide/JJ vaccination/NN)
#   (CHUNK September/NNP)
#   (CHUNK this/DT year/NN)
#   ./.)
# (S
#   This/DT
#   is/VBZ
#   (CHUNK the/DT long-term/JJ solution/NN)
#   of/IN
#   (CHUNK the/DT department/NN)
#   for/IN
#   its/PRP$
#   (CHUNK target/NN)
#   of/IN
#   (CHUNK a/DT measles-free/JJ nation/NN)
#   by/IN
#   2017/CD
#   ''/''
#   (CHUNK Isa/NNP)
#   tayo/VBD
#   (CHUNK sa/JJ pinakaunang/NN)
#   (CHUNK bansa/NN)
#   na/IN
#   (CHUNK nag-target/JJ sa/NN)
#   measles/NNS
#   (CHUNK elimination/NN)
#   (/(
#   We/PRP
#   're/VBP
#   one/CD
#   of/IN
#   the/DT
#   first/JJ
#   countries/NNS
#   to/TO
#   target/VB
#   measles/NNS
#   (CHUNK elimination/NN)
#   )/)
#   ,/,
#   (CHUNK
#     ”/NNP
#     Health/NNP
#     Assistant/NNP
#     Secretary/NNP
#     Eric/NNP
#     Tayag/NNP)
#   said/VBD
#   in/IN
#   (CHUNK a/DT forum/NN)
#   (CHUNK Tuesday/NNP)
#   ,/,
#   (CHUNK January/NNP)
#   7/CD
#   ./.)
# (S
#   He/PRP
#   said/VBD
#   being/VBG
#   measles-free/JJ
#   means/NNS
#   that/IN
#   in/IN
#   (CHUNK a/DT population/NN)
#   of/IN
#   100/CD
#   million/CD
#   ,/,
#   the/DT
#   laboratory-confirmed/JJ
#   cases/NNS
#   should/MD
#   not/RB
#   exceed/VB
#   100/CD
#   people/NNS
#   ./.)
# (S
#   (CHUNK Last/JJ year/NN)
#   ,/,
#   the/DT
#   confirmed/JJ
#   cases/NNS
#   numbered/VBD
#   1,724/CD
#   ./.)
# (S
#   (CHUNK The/DT Philippine/JJ population/NN)
#   is/VBZ
#   92.34/CD
#   million/CD
#   based/VBN
#   on/IN
#   the/DT
#   2010/CD
#   (CHUNK census/NN)
#   ,/,
#   but/CC
#   the/DT
#   (CHUNK Commission/NNP)
#   on/IN
#   (CHUNK Population/NNP)
#   expected/VBD
#   (CHUNK the/DT number/NN)
#   to/TO
#   reach/VB
#   97.7/CD
#   (CHUNK milllion/NN)
#   by/IN
#   2013/CD
#   ./.)
# (S
#   (/(
#   READ/VB
#   :/:
#   (CHUNK DOH/NNP)
#   steps/VBZ
#   up/RP
#   (CHUNK drive/JJ vs/NN)
#   measles/NNS
#   amid/IN
#   (CHUNK outbreak/NN)
#   )/)
#   (CHUNK Tayag/NNP)
#   said/VBD
#   (CHUNK the/DT mass/NN)
#   (CHUNK immunization/NN)
#   will/MD
#   be/VB
#   conducted/VBN
#   for/IN
#   (CHUNK the/DT whole/JJ month/NN)
#   of/IN
#   (CHUNK September/NNP)
#   ,/,
#   targeting/VBG
#   13/CD
#   million/CD
#   children/NNS
#   nationwide/JJ
#   ./.)
# (S
#   Measles/NNS
#   is/VBZ
#   a/DT
#   viral/JJ
#   ,/,
#   (CHUNK highly-contagious/JJ respiratory/NN)
#   (CHUNK disease/NN)
#   ./.)
# (S
#   Infected/VBN
#   persons/NNS
#   (CHUNK exhibit/NN)
#   symptoms/NNS
#   such/JJ
#   as/IN
#   (CHUNK high/JJ fever/NN)
#   ,/,
#   red/JJ
#   eyes/NNS
#   ,/,
#   runny/VBP
#   nose/RB
#   and/CC
#   (CHUNK cough/NN)
#   ./.)
# (S
#   Rashes/NNS
#   appear/VBP
#   throughout/IN
#   (CHUNK the/DT body/NN)
#   after/IN
#   two/CD
#   days/NNS
#   ./.)
# (S
#   (CHUNK The/DT illness/NN)
#   can/MD
#   be/VB
#   spread/VBN
#   through/IN
#   (CHUNK cough/NN)
#   or/CC
#   (CHUNK direct/JJ contact/NN)
#   with/IN
#   (CHUNK body/NN)
#   secretions/NNS
#   of/IN
#   (CHUNK an/DT infected/JJ person/NN)
#   ./.)
# (S
#   (CHUNK A/DT person/NN)
#   with/IN
#   measles/NNS
#   can/MD
#   pass/VB
#   (CHUNK the/DT disease/NN)
#   on/IN
#   to/TO
#   18/CD
#   other/JJ
#   people/NNS
#   ./.)
# (S
#   (CHUNK Role/NNP)
#   of/IN
#   (CHUNK LGUs/NNP Tayag/NNP)
#   urged/VBD
#   parents/NNS
#   in/IN
#   areas/NNS
#   with/IN
#   a/DT
#   measles/NNS
#   outbreak/VBP
#   to/TO
#   have/VB
#   their/PRP$
#   children/NNS
#   vaccinated/VBN
#   regardless/RB
#   of/IN
#   whether/IN
#   they/PRP
#   were/VBD
#   already/RB
#   vaccinated/VBN
#   or/CC
#   not/RB
#   ./.)
# (S
#   Some/DT
#   21/CD
#   barangays/NNS
#   in/IN
#   9/CD
#   cities/NNS
#   have/VBP
#   declared/VBN
#   (CHUNK an/DT outbreak/NN)
#   in/IN
#   their/PRP$
#   areas/NNS
#   ,/,
#   according/VBG
#   to/TO
#   state-run/JJ
#   (CHUNK Philippine/NNP News/NNP Agency/NNP)
#   ./.)
# (S
#   These/DT
#   barangays/NNS
#   include/VBP
#   :/:
#   Caloocan/JJ
#   (CHUNK City/NNP)
#   :/:
#   (CHUNK Bagong/NNP Barrio/NNP)
#   and/CC
#   (CHUNK Dagat-dagatan/NNP Las/NNP Piñas/NNP City/NNP)
#   :/:
#   (CHUNK Pamplona/NNP Uno/NNP)
#   ,/,
#   (CHUNK Talon/NNP Dos/NNP)
#   ,/,
#   and/CC
#   (CHUNK Talon/NNP Singko/NNP Malabon/NNP City/NNP)
#   :/:
#   (CHUNK Longos/NNP)
#   and/CC
#   (CHUNK Tonsuya/NNP Manila/NNP)
#   :/:
#   (CHUNK Binondo/NNP)
#   ,/,
#   (CHUNK Quiapo/NNP)
#   ,/,
#   (CHUNK Port/NNP Area/NNP)
#   ,/,
#   (CHUNK Sampaloc/NNP)
#   ,/,
#   (CHUNK Sta/NNP)
#   ./.)
# (S (CHUNK Cruz/NNP) ,/, (CHUNK Sta/NNP) ./.)
# (S
#   (CHUNK Mesa/NNP)
#   ,/,
#   and/CC
#   (CHUNK Tondo/NNP Muntinlupa/NNP City/NNP)
#   :/:
#   (CHUNK Alabang/NNP)
#   and/CC
#   (CHUNK Putatan/NNP Navotas/NNP)
#   :/:
#   (CHUNK
#     North/NNP
#     Bay/NNP
#     Boulevard/NNP
#     South/NNP
#     Parañaque/NNP
#     City/NNP)
#   :/:
#   (CHUNK Don/NNP Bosco/NNP)
#   and/CC
#   (CHUNK Moonwalk/NNP Taguig/NNP City/NNP)
#   :/:
#   (CHUNK Bagong/NNP Tanyag/NNP Valenzuela/NNP City/NNP)
#   :/:
#   (CHUNK Ugong/NNP Tayag/NNP)
#   said/VBD
#   it/PRP
#   takes/VBZ
#   (CHUNK the/DT department/NN)
#   two/CD
#   weeks/NNS
#   to/TO
#   get/VB
#   (CHUNK confirmation/NN)
#   ,/,
#   but/CC
#   at/IN
#   (CHUNK the/DT local/JJ government/NN)
#   (CHUNK level/NN)
#   ,/,
#   (CHUNK a/DT suspected/JJ case/NN)
#   already/RB
#   prompts/VBZ
#   (CHUNK an/DT investigation/NN)
#   ./.)
# (S
#   (CHUNK Valenzuela/NNP Rep/NNP Sherwin/NNP Gatchalian/NNP)
#   told/VBD
#   (CHUNK the/DT department/NN)
#   that/IN
#   (CHUNK LGUs/NNP)
#   can/MD
#   play/VB
#   (CHUNK a/DT big/JJ role/NN)
#   in/IN
#   preventing/VBG
#   (CHUNK the/DT upsurge/NN)
#   of/IN
#   measles/NNS
#   cases/NNS
#   in/IN
#   the/DT
#   (CHUNK National/NNP Capital/NNP Region/NNP)
#   through/IN
#   (CHUNK information/NN)
#   and/CC
#   (CHUNK mass/NN)
#   (CHUNK vaccination/NN)
#   ./.)
# (S
#   (/(
#   READ/VB
#   :/:
#   (CHUNK DOH/NN)
#   :/:
#   (CHUNK Measles/NNP)
#   (CHUNK upsurge/NN)
#   due/JJ
#   to/TO
#   kids/NNS
#   missing/VBG
#   (CHUNK free/JJ vaccination/NN)
#   )/)
#   ``/``
#   We/PRP
#   can/MD
#   not/RB
#   rely/VB
#   on/IN
#   (CHUNK national/JJ government/NN)
#   all/PDT
#   (CHUNK the/DT time/NN)
#   since/IN
#   things/NNS
#   like/IN
#   these/DT
#   are/VBP
#   best/JJS
#   managed/VBN
#   at/IN
#   (CHUNK the/DT local/JJ level/NN)
#   .../:
#   I/PRP
#   ’/VBP
#   m/RB
#   appealing/VBG
#   to/TO
#   the/DT
#   (CHUNK DOH/NNP)
#   to/TO
#   immediately/RB
#   convene/VB
#   (CHUNK a/DT health/NN)
#   (CHUNK summit/NN)
#   to/TO
#   review/VB
#   (CHUNK the/DT level/NN)
#   of/IN
#   (CHUNK preparedness/NN)
#   of/IN
#   (CHUNK LGUs/NNP)
#   and/CC
#   at/IN
#   (CHUNK the/DT same/JJ time/NN)
#   set/VBN
#   a/DT
#   standard/JJ
#   (CHUNK ‘/NNP)
#   (CHUNK emergency/NN)
#   (CHUNK response/NN)
#   (CHUNK template/NN)
#   (CHUNK ’/NN)
#   should/MD
#   there/RB
#   be/VB
#   (CHUNK any/DT outbreak/NN)
#   ,/,
#   ''/''
#   he/PRP
#   added/VBD
#   ./.)
# (S
#   (CHUNK Health/NNP Secretary/NNP Enrique/NNP Ona/NNP)
#   said/VBD
#   a/DT
#   measles/NNS
#   outbreak/VBP
#   mean/JJ
#   ''/''
#   there/EX
#   have/VBP
#   been/VBN
#   cases/NNS
#   of/IN
#   (CHUNK a/DT disease/NN)
#   (CHUNK –/NN)
#   either/RB
#   suspected/VBD
#   or/CC
#   confirmed/VBD
#   –/NNS
#   in/IN
#   (CHUNK a/DT community/NN)
#   or/CC
#   (CHUNK a/DT locality/NN)
#   where/WRB
#   in/IN
#   (CHUNK the/DT past/NN)
#   there/EX
#   was/VBD
#   (CHUNK none/NN)
#   ./.
#   ''/'')
# (S
#   For/IN
#   (CHUNK Tayag/NNP)
#   ,/,
#   it/PRP
#   means/VBZ
#   (CHUNK any/DT barangay/NN)
#   or/CC
#   (CHUNK district/NN)
#   with/IN
#   at/IN
#   least/JJS
#   one/CD
#   (CHUNK laboratory-confirmed/JJ case/NN)
#   ./.)
# (S
#   (CHUNK “/NN)
#   (CHUNK Lahat/NNP)
#   ng/VBZ
#   (CHUNK baby/NN)
#   starting/VBG
#   6/CD
#   months/NNS
#   hanggang/RB
#   59/CD
#   months/NNS
#   (CHUNK bibigyan/JJ ng/JJ bakuna/NN)
#   regardless/RB
#   kung/VBD
#   nagkatigdas/JJ
#   na/TO
#   o/VB
#   (CHUNK tumanggap/NN)
#   na/TO
#   (CHUNK ng/JJ bakuna/NN)
#   (CHUNK –/NNP)
#   (CHUNK maliban/NN)
#   (CHUNK na/NN)
#   lang/VBD
#   kung/JJR
#   less/JJR
#   than/IN
#   (CHUNK a/DT month/NN)
#   (CHUNK lang/NN)
#   (CHUNK yung/NN)
#   (CHUNK bakuna/NN)
#   ,/,
#   ”/CC
#   he/PRP
#   added/VBD
#   ./.)
# (S
#   (/(
#   All/DT
#   babies/NNS
#   starting/VBG
#   6/CD
#   months/NNS
#   until/IN
#   59/CD
#   months/NNS
#   will/MD
#   be/VB
#   vaccinated/VBN
#   regardless/RB
#   of/IN
#   whether/IN
#   they/PRP
#   already/RB
#   had/VBD
#   measles/NNS
#   or/CC
#   they/PRP
#   were/VBD
#   already/RB
#   vaccinated/VBN
#   (CHUNK –/NNP)
#   unless/IN
#   (CHUNK the/DT vaccination/NN)
#   was/VBD
#   administered/VBN
#   less/JJR
#   than/IN
#   (CHUNK a/DT month/NN)
#   ago/RB
#   ./.
#   )/))
# (S
#   (CHUNK No/DT overdose/NN)
#   But/CC
#   (CHUNK the/DT vaccination/NN)
#   of/IN
#   children/NNS
#   aged/VBN
#   6/CD
#   months/NNS
#   old/JJ
#   is/VBZ
#   only/RB
#   recommended/JJ
#   for/IN
#   places/NNS
#   with/IN
#   (CHUNK an/DT outbreak/NN)
#   ./.)
# (S
#   This/DT
#   is/VBZ
#   3/CD
#   months/NNS
#   earlier/JJR
#   than/IN
#   (CHUNK the/DT prescribed/JJ age/NN)
#   for/IN
#   (CHUNK the/DT first/JJ vaccine/NN)
#   (/(
#   9/CD
#   to/TO
#   11/CD
#   months/NNS
#   )/)
#   which/WDT
#   they/PRP
#   should/MD
#   still/RB
#   get/VB
#   ,/,
#   as/RB
#   well/RB
#   as/IN
#   (CHUNK the/DT booster/NN)
#   (CHUNK shot/NN)
#   at/IN
#   15/CD
#   months/NNS
#   old/JJ
#   ./.)
# (S
#   (CHUNK The/DT first/JJ vaccine/NN)
#   is/VBZ
#   90/CD
#   (CHUNK %/NN)
#   effective/JJ
#   ,/,
#   while/IN
#   (CHUNK the/DT booster/NN)
#   is/VBZ
#   100/CD
#   (CHUNK %/NN)
#   effective/JJ
#   ,/,
#   (CHUNK Tayag/NNP)
#   said/VBD
#   ./.)
# (S
#   (CHUNK “/NN)
#   (CHUNK Between/NNP)
#   (CHUNK isang/NN)
#   (CHUNK bakuna/NN)
#   at/IN
#   (CHUNK wala/NN)
#   ,/,
#   (CHUNK lamang/NN)
#   (CHUNK ang/NN)
#   (CHUNK isang/NN)
#   (CHUNK bakuna/NN)
#   ./.)
# (S
#   (CHUNK Kaya/NNP)
#   kahit/VBD
#   alam/JJ
#   namin/RB
#   na/TO
#   baka/VB
#   (CHUNK di/JJ siya/NN)
#   (CHUNK maproteksyunan/NN)
#   .../:
#   (CHUNK yung/NN)
#   may/MD
#   bakuna/VB
#   ,/,
#   lamang/FW
#   na/FW
#   lamang/FW
#   dun/FW
#   sa/FW
#   'di/FW
#   nakatanggap/FW
#   ng/FW
#   (CHUNK bakuna/NN)
#   ./.)
# (S
#   (CHUNK Subali't/NNP)
#   alam/VBZ
#   namin/RB
#   na/JJ
#   'di/CD
#   (CHUNK sapat/JJ yun/NN)
#   (CHUNK kaya/NN)
#   kailangan/VBD
#   (CHUNK ulitin/JJ sa/NN)
#   (CHUNK tamang/NN)
#   (CHUNK panahon/NN)
#   ,/,
#   ”/CC
#   he/PRP
#   added/VBD
#   ./.)
# (S
#   (/(
#   It/PRP
#   's/VBZ
#   better/JJR
#   to/TO
#   be/VB
#   vaccinated/VBN
#   than/IN
#   not/RB
#   ./.)
# (S
#   So/RB
#   even/RB
#   though/IN
#   we/PRP
#   know/VBP
#   (CHUNK the/DT child/NN)
#   may/MD
#   not/RB
#   be/VB
#   protected/VBN
#   .../:
#   (CHUNK the/DT vaccinated/JJ child/NN)
#   has/VBZ
#   (CHUNK an/DT advantage/NN)
#   compared/VBN
#   to/TO
#   the/DT
#   one/CD
#   not/RB
#   vaccinated/VBN
#   ./.)
# (S
#   But/CC
#   we/PRP
#   know/VBP
#   that/DT
#   is/VBZ
#   not/RB
#   enough/RB
#   so/IN
#   (CHUNK the/DT vaccine/NN)
#   should/MD
#   be/VB
#   given/VBN
#   again/RB
#   at/IN
#   (CHUNK the/DT right/JJ time/NN)
#   ./.
#   )/))
# (S
#   In/IN
#   normal/JJ
#   conditions/NNS
#   ,/,
#   6/CD
#   months/NNS
#   old/JJ
#   is/VBZ
#   too/RB
#   early/JJ
#   for/IN
#   a/DT
#   measles/NNS
#   (CHUNK vaccination/NN)
#   because/IN
#   maternal/JJ
#   antibodies/NNS
#   still/RB
#   persist/VBP
#   in/IN
#   (CHUNK the/DT baby/NN)
#   ,/,
#   rendering/VBG
#   (CHUNK the/DT vaccine/NN)
#   (CHUNK useless/NN)
#   ./.)
# (S
#   But/CC
#   during/IN
#   outbreaks/NNS
#   ,/,
#   (CHUNK the/DT vaccine/NN)
#   is/VBZ
#   given/VBN
#   at/IN
#   6/CD
#   months/NNS
#   old/JJ
#   because/RB
#   ,/,
#   as/IN
#   (CHUNK Tayag/NNP)
#   said/VBD
#   ,/,
#   (CHUNK “/NNP)
#   nagbabakasakali/FW
#   ka/FW
#   na/FW
#   wala/FW
#   na/FW
#   (CHUNK yung/NN)
#   antibodies/NNS
#   at/IN
#   (CHUNK kakagat/NN)
#   (CHUNK na/NN)
#   (CHUNK yung/NN)
#   (CHUNK bakuna./NN)
#   (CHUNK ”/NNP)
#   (/(
#   You/PRP
#   're/VBP
#   hoping/VBG
#   there/EX
#   are/VBP
#   no/DT
#   more/JJR
#   antibodies/NNS
#   and/CC
#   (CHUNK the/DT vaccine/NN)
#   will/MD
#   take/VB
#   (CHUNK effect/NN)
#   ./.
#   )/))
# (S
#   (CHUNK Dr/NNP Beatriz/NNP Quiambao/NNP)
#   ,/,
#   (CHUNK president/NN)
#   of/IN
#   the/DT
#   (CHUNK Pediatric/NNP Infectious/NNP Disease/NNP Society/NNP)
#   of/IN
#   the/DT
#   Philippines/NNPS
#   ,/,
#   told/VBD
#   parents/NNS
#   not/RB
#   to/TO
#   worry/VB
#   ,/,
#   as/IN
#   there/EX
#   is/VBZ
#   (CHUNK no/DT such/JJ thing/NN)
#   as/IN
#   (CHUNK an/DT overdose/NN)
#   when/WRB
#   getting/VBG
#   more/JJR
#   than/IN
#   (CHUNK the/DT prescribed/JJ number/NN)
#   of/IN
#   vaccines/NNS
#   ./.)
# (S
#   (CHUNK Tayag/NN)
#   again/RB
#   urged/VBD
#   parents/NNS
#   to/TO
#   avail/VB
#   of/IN
#   the/DT
#   free/JJ
#   vaccines/NNS
#   ,/,
#   which/WDT
#   he/PRP
#   said/VBD
#   ,/,
#   is/VBZ
#   (CHUNK the/DT only/JJ prevention/NN)
#   against/IN
#   measles/NNS
#   ./.)
# (S
#   And/CC
#   while/IN
#   it/PRP
#   is/VBZ
#   possible/JJ
#   to/TO
#   prevent/VB
#   complications/NNS
#   ,/,
#   he/PRP
#   said/VBD
#   people/NNS
#   (CHUNK die/NN)
#   of/IN
#   measles/NNS
#   mainly/RB
#   because/IN
#   they/PRP
#   are/VBP
#   malnourished/VBN
#   or/CC
#   brought/VBN
#   to/TO
#   (CHUNK the/DT hospital/NN)
#   too/RB
#   late/RB
#   ./.)
# (S
#   (CHUNK Last/JJ year/NN)
#   ,/,
#   (CHUNK the/DT department/NN)
#   recorded/VBD
#   21/CD
#   deaths/NNS
#   due/JJ
#   to/TO
#   measles/NNS
#   ./.)
# (S
#   (CHUNK MANILA/NNP)
#   ,/,
#   (CHUNK Philippines—The/NNP Department/NNP)
#   of/IN
#   (CHUNK Health/NNP)
#   appealed/VBD
#   to/TO
#   parents/NNS
#   to/TO
#   have/VB
#   their/PRP$
#   children/NNS
#   vaccinated/VBN
#   against/IN
#   measles/NNS
#   on/IN
#   (CHUNK Friday/NNP)
#   as/IN
#   it/PRP
#   declared/VBD
#   (CHUNK an/DT outbreak/NN)
#   of/IN
#   (CHUNK the/DT disease/NN)
#   in/IN
#   (CHUNK Metro/NNP Manila/NNP)
#   and/CC
#   other/JJ
#   parts/NNS
#   of/IN
#   (CHUNK the/DT country/NN)
#   ./.)
# (S
#   (CHUNK
#     Health/NNP
#     Assistant/NNP
#     Secretary/NNP
#     Dr./NNP
#     Eric/NNP
#     Tayag/NNP)
#   ,/,
#   who/WP
#   is/VBZ
#   also/RB
#   (CHUNK director/NN)
#   of/IN
#   the/DT
#   (CHUNK National/NNP Epidemiology/NNP Center/NNP)
#   ,/,
#   said/VBD
#   that/IN
#   from/IN
#   (CHUNK Jan./NNP)
#   1/CD
#   to/TO
#   (CHUNK Dec./NNP)
#   14/CD
#   ,/,
#   2013/CD
#   ,/,
#   there/EX
#   were/VBD
#   already/RB
#   1,724/CD
#   confirmed/VBD
#   measles/NNS
#   cases/NNS
#   nationwide/RB
#   ,/,
#   21/CD
#   of/IN
#   which/WDT
#   led/VBD
#   to/TO
#   (CHUNK death/NN)
#   ./.)
# (S
#   He/PRP
#   added/VBD
#   that/IN
#   among/IN
#   the/DT
#   17/CD
#   regions/NNS
#   in/IN
#   (CHUNK the/DT country/NN)
#   ,/,
#   only/RB
#   four/CD
#   did/VBD
#   not/RB
#   report/VB
#   (CHUNK an/DT increase/NN)
#   in/IN
#   (CHUNK the/DT number/NN)
#   of/IN
#   measles/NNS
#   cases/NNS
#   ./.)
# (S
#   These/DT
#   are/VBP
#   (CHUNK Central/NNP Visayas/NNP)
#   ,/,
#   (CHUNK Eastern/NNP Visayas/NNP)
#   ,/,
#   (CHUNK Northern/NNP Mindanao/NNP)
#   and/CC
#   the/DT
#   (CHUNK Caraga/NNP)
#   (CHUNK region/NN)
#   in/IN
#   (CHUNK Mindanao/NNP)
#   ./.)
# (S
#   The/DT
#   (CHUNK National/NNP Capital/NNP Region/NNP)
#   had/VBD
#   the/DT
#   most/RBS
#   (CHUNK number/NN)
#   of/IN
#   cases/NNS
#   with/IN
#   744/CD
#   ./.)
# (S
#   (CHUNK Measles/NNP)
#   outbreak/PRP
#   had/VBD
#   been/VBN
#   declared/VBN
#   in/IN
#   the/DT
#   following/JJ
#   (CHUNK Metro/NNP Manila/NNP)
#   areas/NNS
#   :/:
#   (CHUNK Quiapo/NNP)
#   ,/,
#   (CHUNK Sampaloc/NNP)
#   ,/,
#   (CHUNK Tondo/NNP)
#   ,/,
#   (CHUNK Binondo/NNP)
#   ,/,
#   (CHUNK Sta/NNP)
#   ./.)
# (S
#   (CHUNK Cruz/NNP)
#   ,/,
#   (CHUNK Port/NNP Area/NNP)
#   and/CC
#   (CHUNK Sta/NNP)
#   ./.)
# (S
#   (CHUNK Mesa/NNP)
#   in/IN
#   (CHUNK Manila/NNP)
#   ;/:
#   (CHUNK Dagat-dagatan/NNP)
#   and/CC
#   (CHUNK Bagong/NNP Barrio/NNP)
#   ,/,
#   in/IN
#   (CHUNK Caloocan/NNP City/NNP)
#   ;/:
#   (CHUNK Talon/NNP)
#   5/CD
#   ,/,
#   (CHUNK Talon/NNP)
#   2/CD
#   and/CC
#   (CHUNK Pamplona/NNP Uno/NNP)
#   in/IN
#   (CHUNK Las/NNP Piñas/NNP)
#   ;/:
#   (CHUNK Longos/NNP)
#   and/CC
#   (CHUNK Tonsuya/NNP)
#   in/IN
#   (CHUNK Malabon/NNP)
#   ;/:
#   (CHUNK Alabang/NNP)
#   and/CC
#   (CHUNK Putatan/NNP)
#   in/IN
#   (CHUNK Muntinlupa/NNP)
#   ;/:
#   (CHUNK North/NNP Bay/NNP Boulevard/NNP South/NNP)
#   in/IN
#   (CHUNK Navotas/NNP)
#   ;/:
#   (CHUNK Moonwalk/NNP)
#   and/CC
#   (CHUNK Don/NNP Bosco/NNP)
#   in/IN
#   (CHUNK Parañaque/NNP)
#   ;/:
#   (CHUNK Bagong/NNP Tanyag/NNP)
#   in/IN
#   (CHUNK Taguig/NNP)
#   ;/:
#   and/CC
#   (CHUNK Ugong/NNP)
#   in/IN
#   (CHUNK Valenzuela/NNP)
#   ./.)
# (S
#   But/CC
#   (CHUNK Tayag/NNP)
#   noted/VBD
#   that/IN
#   (CHUNK mass/NN)
#   vaccinations/NNS
#   had/VBD
#   already/RB
#   been/VBN
#   conducted/VBN
#   in/IN
#   those/DT
#   places/NNS
#   ./.)
# (S
#   He/PRP
#   said/VBD
#   (CHUNK mass/NN)
#   vaccinations/NNS
#   would/MD
#   also/RB
#   soon/RB
#   be/VB
#   conducted/VBN
#   nationwide/JJ
#   ,/,
#   preferably/RB
#   during/IN
#   (CHUNK the/DT summer/NN)
#   (CHUNK break/NN)
#   ./.)
# (S
#   He/PRP
#   urged/VBD
#   parents/NNS
#   to/TO
#   bring/VB
#   their/PRP$
#   children/NNS
#   ,/,
#   especially/RB
#   those/DT
#   between/IN
#   the/DT
#   ages/NNS
#   of/IN
#   6/CD
#   to/TO
#   18/CD
#   months/NNS
#   ,/,
#   to/TO
#   (CHUNK health/NN)
#   centers/NNS
#   for/IN
#   (CHUNK free/JJ vaccination/NN)
#   ./.)
# (S
#   (CHUNK Tayag/NNP)
#   noted/VBD
#   that/IN
#   measles/NNS
#   is/VBZ
#   (CHUNK a/DT contagious/JJ viral/JJ illness/NN)
#   ,/,
#   which/WDT
#   can/MD
#   be/VB
#   deadly/RB
#   ./.)
# (S
#   He/PRP
#   said/VBD
#   it/PRP
#   commonly/RB
#   spreads/VBZ
#   among/IN
#   children/NNS
#   and/CC
#   even/RB
#   adults/NNS
#   ,/,
#   but/CC
#   the/DT
#   most/RBS
#   susceptible/JJ
#   are/VBP
#   children/NNS
#   10/CD
#   years/NNS
#   old/JJ
#   and/CC
#   (CHUNK below/NN)
#   ./.)
# (S
#   He/PRP
#   said/VBD
#   infants/NNS
#   and/CC
#   children/NNS
#   with/IN
#   measles/NNS
#   should/MD
#   be/VB
#   hospitalized/VBN
#   ./.)
# (S
#   Children/$
#   6/CD
#   to/TO
#   18/CD
#   months/NNS
#   old/JJ
#   must/MD
#   complete/VB
#   the/DT
#   required/JJ
#   two/CD
#   vaccinations/NNS
#   to/TO
#   prevent/VB
#   them/PRP
#   from/IN
#   contracting/VBG
#   measles/NNS
#   ,/,
#   he/PRP
#   said/VBD
#   ./.)
# (S
#   Newborn/JJ
#   children/NNS
#   must/MD
#   take/VB
#   (CHUNK the/DT first/JJ preventive/JJ vaccine/NN)
#   (CHUNK shot/NN)
#   for/IN
#   measles/NNS
#   upon/IN
#   reaching/VBG
#   6/CD
#   months/NNS
#   to/TO
#   12/CD
#   months/NNS
#   ./.)
# (S
#   (CHUNK The/DT second/JJ vaccine/NN)
#   (CHUNK shot/NN)
#   should/MD
#   be/VB
#   taken/VBN
#   upon/IN
#   reaching/VBG
#   (CHUNK the/DT age/NN)
#   of/IN
#   12/CD
#   months/NNS
#   to/TO
#   18/CD
#   months/NNS
#   ./.)
# (S
#   “/IN
#   These/DT
#   two/CD
#   consecutive/JJ
#   shots/NNS
#   must/MD
#   be/VB
#   taken/VBN
#   to/TO
#   avoid/VB
#   having/VBG
#   (CHUNK the/DT risk/NN)
#   of/IN
#   getting/VBG
#   measles/NNS
#   ,/,
#   (CHUNK ”/NN)
#   he/PRP
#   said/VBD
#   ./.)
# (S
#   He/PRP
#   said/VBD
#   measles/NNS
#   usually/RB
#   begins/VBZ
#   with/IN
#   (CHUNK common/JJ cold/NN)
#   symptoms/NNS
#   like/IN
#   (CHUNK high/JJ fever/NN)
#   ,/,
#   (CHUNK cough/NN)
#   ,/,
#   (CHUNK runny/NN)
#   nose/RB
#   ,/,
#   red/JJ
#   eyes/NNS
#   that/WDT
#   can/MD
#   last/JJ
#   for/IN
#   several/JJ
#   days/NNS
#   before/IN
#   (CHUNK the/DT appearance/NN)
#   of/IN
#   a/DT
#   red/JJ
#   ,/,
#   (CHUNK blotchy/JJ rash/NN)
#   ./.)
# (S
#   (CHUNK Tayag/NNP)
#   suggested/VBD
#   that/IN
#   parents/NNS
#   bring/VBP
#   down/RP
#   (CHUNK the/DT fever/NN)
#   with/IN
#   (CHUNK paracetamol/NN)
#   and/CC
#   (CHUNK sponge/NN)
#   (CHUNK bath/NN)
#   to/TO
#   prevent/VB
#   (CHUNK the/DT onset/NN)
#   of/IN
#   convulsions/NNS
#   ,/,
#   and/CC
#   to/TO
#   get/VB
#   rid/JJ
#   of/IN
#   the/DT
#   thick/JJ
#   discharges/NNS
#   from/IN
#   (CHUNK the/DT nose/NN)
#   ./.)
# (S
#   He/PRP
#   also/RB
#   urged/VBD
#   parents/NNS
#   to/TO
#   count/VB
#   (CHUNK a/DT child/NN)
#   (CHUNK ’/NNP)
#   (CHUNK s/NN)
#   inhalations/NNS
#   ,/,
#   noting/VBG
#   (CHUNK a/DT child/NN)
#   less/JJR
#   than/IN
#   five/CD
#   years/NNS
#   old/JJ
#   with/IN
#   more/JJR
#   than/IN
#   40/CD
#   breaths/NNS
#   per/IN
#   (CHUNK minute/NN)
#   may/MD
#   have/VB
#   (CHUNK pneumonia/NN)
#   ./.)
# (S
#   At/IN
#   least/JJS
#   seven/CD
#   children/NNS
#   died/VBD
#   due/JJ
#   to/TO
#   measles/NNS
#   in/IN
#   (CHUNK Davao/NNP City/NNP)
#   in/IN
#   (CHUNK August/NNP)
#   ,/,
#   a/DT
#   (CHUNK Mindanao/NNP)
#   (CHUNK news/NN)
#   (CHUNK site/NN)
#   quoted/VBD
#   (CHUNK a/DT city/NN)
#   (CHUNK health/NN)
#   (CHUNK official/NN)
#   as/IN
#   saying/VBG
#   late/JJ
#   (CHUNK Saturday/NNP)
#   ./.)
# (S
#   (CHUNK City/NNP Health/NNP Office/NNP)
#   (CHUNK immunization/NN)
#   (CHUNK head/NN)
#   (CHUNK Armi/NNP Capili/NNP)
#   said/VBD
#   (CHUNK the/DT spike/NN)
#   in/IN
#   such/JJ
#   cases/NNS
#   was/VBD
#   due/JJ
#   to/TO
#   many/JJ
#   mothers/NNS
#   '/POS
#   (CHUNK failure/NN)
#   to/TO
#   have/VB
#   their/PRP$
#   children/NNS
#   immunized/VBN
#   ,/,
#   (CHUNK MindaNews/NNP)
#   reported/VBD
#   ./.)
# (S
#   She/PRP
#   said/VBD
#   (CHUNK another/DT reason/NN)
#   could/MD
#   be/VB
#   (CHUNK the/DT disease/NN)
#   's/POS
#   (CHUNK contagious/JJ nature/NN)
#   where/WRB
#   one/CD
#   (CHUNK case/NN)
#   can/MD
#   contaminate/VB
#   up/RB
#   to/TO
#   20/CD
#   people/NNS
#   ./.)
# (S
#   Of/IN
#   some/DT
#   1,228/CD
#   suspected/VBD
#   measles/NNS
#   cases/NNS
#   as/IN
#   of/IN
#   (CHUNK August/NNP)
#   27/CD
#   ,/,
#   120/CD
#   have/VBP
#   been/VBN
#   confirmed/VBN
#   so/RB
#   far/RB
#   ./.)
# (S
#   As/IN
#   of/IN
#   (CHUNK August/NNP)
#   8/CD
#   ,/,
#   the/DT
#   (CHUNK CHO/NNP)
#   said/VBD
#   most/JJS
#   reports/NNS
#   of/IN
#   suspected/JJ
#   measles/NNS
#   cases/NNS
#   came/VBD
#   from/IN
#   (CHUNK Talomo/NNP North/NNP)
#   with/IN
#   201/CD
#   ,/,
#   (CHUNK Talomo/NNP South/NNP)
#   with/IN
#   133/CD
#   ,/,
#   and/CC
#   (CHUNK Buhangin/NNP)
#   with/IN
#   116/CD
#   ./.)
# (S
#   In/IN
#   2012/CD
#   ,/,
#   (CHUNK Capili/NNP)
#   said/VBD
#   there/EX
#   were/VBD
#   only/RB
#   four/CD
#   confirmed/VBD
#   cases/NNS
#   in/IN
#   (CHUNK Davao/NNP City/NNP)
#   ./.)
# (S
#   She/PRP
#   said/VBD
#   this/DT
#   could/MD
#   be/VB
#   due/JJ
#   to/TO
#   (CHUNK an/DT intensified/JJ immunization/NN)
#   (CHUNK campaign/NN)
#   in/IN
#   2011/CD
#   ./.)
# (S There/EX were/VBD 50/CD confirmed/JJ cases/NNS in/IN 2013/CD ./.)
# (S
#   (CHUNK Department/NNP)
#   of/IN
#   (CHUNK Health/NNP)
#   (CHUNK regional/JJ unit/NN)
#   (CHUNK head/NN)
#   for/IN
#   (CHUNK health/NN)
#   (CHUNK education/NN)
#   and/CC
#   (CHUNK promotion/NN)
#   (CHUNK Divene/NNP Hilario/NNP)
#   said/VBD
#   (CHUNK the/DT total/JJ regional/JJ prevalence/NN)
#   of/IN
#   measles/NNS
#   in/IN
#   2013/CD
#   was/VBD
#   only/RB
#   129/CD
#   ./.)
# (S
#   (CHUNK Capili/NNP)
#   said/VBD
#   (CHUNK the/DT department/NN)
#   will/MD
#   head/VB
#   (CHUNK a/DT massive/JJ immunization/NN)
#   (CHUNK program/NN)
#   for/IN
#   measles/NNS
#   ,/,
#   (CHUNK rubela/NN)
#   ,/,
#   and/CC
#   (CHUNK polio/NN)
#   from/IN
#   (CHUNK September/NNP)
#   1/CD
#   to/TO
#   30/CD
#   at/IN
#   (CHUNK health/NN)
#   centers/NNS
#   and/CC
#   (CHUNK other/JJ vaccination/NN)
#   points/NNS
#   ./.)
# (S (CHUNK Miscommunication/NN) ?/.)
# (S
#   MindaNews/NNS
#   quoted/VBN
#   (CHUNK Hilario/NNP)
#   as/IN
#   saying/VBG
#   there/EX
#   may/MD
#   be/VB
#   (CHUNK a/DT miscommunication/NN)
#   with/IN
#   mothers/NNS
#   on/IN
#   (CHUNK immunization/NN)
#   against/IN
#   measles/NNS
#   ./.)
# (S
#   ``/``
#   (CHUNK The/DT problem/NN)
#   is/VBZ
#   that/IN
#   some/DT
#   parents/NNS
#   do/VBP
#   not/RB
#   take/VB
#   their/PRP$
#   children/NNS
#   back/RB
#   to/TO
#   (CHUNK the/DT health/NN)
#   centers/NNS
#   after/IN
#   the/DT
#   prescribed/JJ
#   nine/CD
#   months/NNS
#   for/IN
#   (CHUNK a/DT second/JJ shot/NN)
#   ,/,
#   ''/''
#   she/PRP
#   said/VBD
#   ./.)
# (S
#   She/PRP
#   said/VBD
#   parents/NNS
#   need/VBP
#   to/TO
#   take/VB
#   their/PRP$
#   children/NNS
#   to/TO
#   the/DT
#   centers/NNS
#   again/RB
#   for/IN
#   (CHUNK a/DT second/JJ booster/NN)
#   (CHUNK dose/NN)
#   ./.)
# (S
#   In/IN
#   (CHUNK the/DT meantime/NN)
#   ,/,
#   the/DT
#   (CHUNK City/NNP Health/NNP Office/NNP)
#   urged/VBD
#   parents/NNS
#   to/TO
#   take/VB
#   their/PRP$
#   children/NNS
#   below/IN
#   five/CD
#   years/NNS
#   old/JJ
#   for/IN
#   (CHUNK free/JJ vaccination/NN)
#   during/IN
#   (CHUNK September/NNP)
#   ./.)
# (S
#   On/IN
#   (CHUNK the/DT other/JJ hand/NN)
#   ,/,
#   (CHUNK CHO/NNP)
#   (CHUNK assistant/JJ officer/NN)
#   for/IN
#   operations/NNS
#   (CHUNK Marjorie/NNP Culas/NNP)
#   said/VBD
#   the/DT
#   expanded/VBN
#   (CHUNK immunization/NN)
#   (CHUNK campaign/NN)
#   may/MD
#   have/VB
#   been/VBN
#   (CHUNK a/DT victim/NN)
#   of/IN
#   (CHUNK online/JJ misinformation/NN)
#   ./.)
# (S
#   (CHUNK Culas/NNP)
#   cited/VBD
#   (CHUNK online/JJ information/NN)
#   claiming/VBG
#   (CHUNK “/NNP)
#   bad/JJ
#   effects/NNS
#   (CHUNK ”/NN)
#   of/IN
#   (CHUNK immunization/NN)
#   such/JJ
#   as/IN
#   (CHUNK a/DT cause/NN)
#   of/IN
#   (CHUNK abortion/NN)
#   and/CC
#   (CHUNK autism/NN)
#   ./.)
# (S
#   (CHUNK MANILA/NNP)
#   ,/,
#   (CHUNK Philippines/NNP)
#   -/:
#   (CHUNK The/DT health/NN)
#   (CHUNK department/NN)
#   on/IN
#   (CHUNK Monday/NNP)
#   ,/,
#   (CHUNK March/NNP)
#   5/CD
#   ,/,
#   declared/VBD
#   (CHUNK a/DT typhoid/JJ fever/NN)
#   (CHUNK outbreak/NN)
#   in/IN
#   54/CD
#   barangays/NNS
#   in/IN
#   (CHUNK Tuburan/NNP)
#   ,/,
#   (CHUNK Cebu/NNP)
#   ./.)
# (S
#   As/RB
#   much/JJ
#   as/IN
#   400/CD
#   individuals/NNS
#   in/IN
#   (CHUNK the/DT area/NN)
#   have/VBP
#   been/VBN
#   afflicted/VBN
#   by/IN
#   (CHUNK the/DT disease/NN)
#   ./.)
# (S
#   (CHUNK The/DT number/NN)
#   of/IN
#   cases/NNS
#   was/VBD
#   observed/VBN
#   to/TO
#   have/VB
#   started/VBN
#   piling/VBG
#   up/RP
#   last/JJ
#   (CHUNK February/NNP)
#   22/CD
#   ./.)
# (S
#   Of/IN
#   the/DT
#   400/CD
#   reported/VBD
#   cases/NNS
#   ,/,
#   31/CD
#   were/VBD
#   confined/VBN
#   in/IN
#   hospitals/NNS
#   in/IN
#   (CHUNK Tuburan/NNP)
#   ,/,
#   (CHUNK a/DT coastal/JJ town/NN)
#   located/VBD
#   (CHUNK north/NN)
#   of/IN
#   (CHUNK Cebu/NNP City/NNP)
#   ./.)
# (S
#   (CHUNK Department/NNP)
#   of/IN
#   (CHUNK Health/NNP Assistant/NNP Secretary/NNP Eric/NNP Tayag/NNP)
#   said/VBD
#   (CHUNK the/DT department/NN)
#   is/VBZ
#   eyeing/VBG
#   ``/``
#   (CHUNK contaminated/JJ water/NN)
#   ''/''
#   as/IN
#   (CHUNK the/DT cause/NN)
#   of/IN
#   (CHUNK the/DT outbreak/NN)
#   ./.)
# (S
#   He/PRP
#   said/VBD
#   ,/,
#   however/RB
#   ,/,
#   that/IN
#   it/PRP
#   is/VBZ
#   not/RB
#   clear/JJ
#   yet/RB
#   whether/IN
#   (CHUNK the/DT contaminated/JJ water/NN)
#   came/VBD
#   from/IN
#   pipelines/NNS
#   or/CC
#   deep/JJ
#   wells/NNS
#   ,/,
#   the/DT
#   two/CD
#   sources/NNS
#   of/IN
#   residents/NNS
#   for/IN
#   their/PRP$
#   (CHUNK water/NN)
#   ./.)
# (S
#   (CHUNK Tayag/NNP)
#   said/VBD
#   (CHUNK the/DT health/NN)
#   (CHUNK department/NN)
#   has/VBZ
#   already/RB
#   dispatched/VBN
#   teams/NNS
#   to/TO
#   look/VB
#   into/IN
#   (CHUNK the/DT outbreak/NN)
#   ./.)
# (S
#   Meantime/RB
#   ,/,
#   he/PRP
#   advised/VBD
#   residents/NNS
#   of/IN
#   the/DT
#   affected/JJ
#   areas/NNS
#   to/TO
#   boil/VB
#   or/CC
#   disinfect/VB
#   (CHUNK water/NN)
#   ,/,
#   while/IN
#   (CHUNK health/NN)
#   officials/NNS
#   are/VBP
#   waiting/VBG
#   for/IN
#   (CHUNK lab/NN)
#   results/NNS
#   on/IN
#   (CHUNK the/DT water/NN)
#   tests/NNS
#   ./.)
# (S
#   (CHUNK Tayag/NNP)
#   said/VBD
#   antibiotics/NNS
#   were/VBD
#   already/RB
#   distributed/VBN
#   to/TO
#   those/DT
#   requiring/VBG
#   (CHUNK treatment/NN)
#   ./.)
# (S
#   This/DT
#   is/VBZ
#   to/TO
#   prevent/VB
#   deaths/NNS
#   due/JJ
#   to/TO
#   (CHUNK intestinal/JJ hemorrhage/NN)
#   or/CC
#   (CHUNK severe/JJ bacterial/JJ infection/NN)
#   ./.)
# (S
#   Potentially/RB
#   (CHUNK fatal/JJ disease/NN)
#   (CHUNK Typhoid/NNP)
#   (CHUNK fever/NN)
#   is/VBZ
#   (CHUNK a/DT life-threatening/JJ illness/NN)
#   caused/VBN
#   by/IN
#   (CHUNK the/DT bacterium/NN)
#   (CHUNK Salmonella/NNP Typhi/NNP)
#   ./.)
# (S
#   (CHUNK A/DT person/NN)
#   can/MD
#   get/VB
#   it/PRP
#   from/IN
#   (CHUNK food/NN)
#   or/CC
#   (CHUNK drink/NN)
#   contaminated/VBN
#   by/IN
#   the/DT
#   feces/NNS
#   or/CC
#   (CHUNK urine/NN)
#   of/IN
#   infected/JJ
#   people/NNS
#   ./.)
# (S
#   (CHUNK Typhoid/NNP)
#   symptoms/NNS
#   usually/RB
#   develop/VBP
#   1–3/CD
#   weeks/NNS
#   after/IN
#   (CHUNK exposure/NN)
#   ,/,
#   and/CC
#   may/MD
#   be/VB
#   mild/JJ
#   or/CC
#   severe/JJ
#   ./.)
# (S
#   (CHUNK Symptoms/NNP)
#   include/VBP
#   (CHUNK high/JJ fever/NN)
#   ,/,
#   (CHUNK malaise/NN)
#   ,/,
#   (CHUNK headache/NN)
#   ,/,
#   (CHUNK constipation/NN)
#   or/CC
#   (CHUNK diarrhea/NN)
#   ,/,
#   rose-colored/JJ
#   spots/NNS
#   on/IN
#   (CHUNK the/DT chest/NN)
#   ,/,
#   and/CC
#   (CHUNK an/DT enlarged/JJ spleen/NN)
#   and/CC
#   (CHUNK liver/NN)
#   ./.)
# (S
#   Even/RB
#   after/IN
#   symptoms/NNS
#   go/VB
#   away/RB
#   ,/,
#   those/DT
#   afflicted/VBN
#   may/MD
#   still/RB
#   be/VB
#   carrying/VBG
#   (CHUNK Salmonella/NNP Typhi/NNP)
#   ,/,
#   according/VBG
#   to/TO
#   (CHUNK information/NN)
#   published/VBN
#   by/IN
#   the/DT
#   Atlanta-based/JJ
#   Centers/NNPS
#   for/IN
#   (CHUNK Disease/NNP Control/NNP)
#   and/CC
#   (CHUNK Prevention/NNP)
#   (/(
#   (CHUNK CDC/NNP)
#   )/)
#   ./.)
# (S
#   This/DT
#   means/VBZ
#   (CHUNK the/DT illness/NN)
#   could/MD
#   return/VB
#   ,/,
#   or/CC
#   (CHUNK the/DT person/NN)
#   previously/RB
#   afflicted/VBN
#   could/MD
#   pass/VB
#   (CHUNK the/DT disease/NN)
#   to/TO
#   other/JJ
#   people/NNS
#   ./.)
# (S
#   How/WRB
#   to/TO
#   avoid/VB
#   typhoid/VB
#   The/DT
#   (CHUNK CDC/NNP)
#   lists/VBZ
#   down/RP
#   the/DT
#   following/JJ
#   tips/NNS
#   to/TO
#   avoid/VB
#   (CHUNK typhoid/NN)
#   :/:
#   If/IN
#   you/PRP
#   drink/VBP
#   (CHUNK water/NN)
#   ,/,
#   buy/VB
#   it/PRP
#   bottled/VBD
#   or/CC
#   bring/VB
#   it/PRP
#   to/TO
#   (CHUNK a/DT rolling/JJ boil/NN)
#   for/IN
#   1/CD
#   (CHUNK minute/NN)
#   before/IN
#   you/PRP
#   drink/VBP
#   it/PRP
#   ./.)
# (S
#   (CHUNK Ask/NNP)
#   for/IN
#   drinks/NNS
#   without/IN
#   (CHUNK ice/NN)
#   --/:
#   unless/IN
#   (CHUNK the/DT ice/NN)
#   is/VBZ
#   made/VBN
#   from/IN
#   bottled/JJ
#   or/CC
#   (CHUNK boiled/JJ water/NN)
#   ./.)
# (S
#   (CHUNK Avoid/NNP)
#   popsicles/NNS
#   and/CC
#   flavored/VBD
#   ices/NNS
#   that/WDT
#   may/MD
#   have/VB
#   been/VBN
#   made/VBN
#   with/IN
#   (CHUNK contaminated/JJ water/NN)
#   ./.)
# (S
#   (CHUNK Eat/NNP)
#   foods/NNS
#   that/WDT
#   have/VBP
#   been/VBN
#   thoroughly/RB
#   cooked/VBN
#   and/CC
#   that/DT
#   are/VBP
#   still/RB
#   hot/JJ
#   and/CC
#   (CHUNK steaming/NN)
#   ./.)
# (S
#   (CHUNK Avoid/NNP)
#   raw/JJ
#   vegetables/NNS
#   and/CC
#   fruits/NNS
#   that/WDT
#   can/MD
#   not/RB
#   be/VB
#   peeled/VBN
#   ./.)
# (S
#   Vegetables/NNS
#   like/IN
#   lettuce/NNS
#   are/VBP
#   easily/RB
#   contaminated/VBN
#   and/CC
#   are/VBP
#   very/RB
#   hard/RB
#   to/TO
#   wash/VB
#   well/RB
#   ./.)
# (S
#   When/WRB
#   you/PRP
#   eat/VBP
#   (CHUNK raw/JJ fruit/NN)
#   or/CC
#   vegetables/NNS
#   that/WDT
#   can/MD
#   be/VB
#   peeled/VBN
#   ,/,
#   peel/VB
#   them/PRP
#   yourself/PRP
#   ./.)
# (S
#   (/(
#   Wash/VB
#   your/PRP$
#   hands/NNS
#   with/IN
#   (CHUNK soap/NN)
#   first/RB
#   ./.
#   )/))
# (S (CHUNK Do/NNP) not/RB eat/VB the/DT peelings/NNS ./.)
# (S
#   (CHUNK Avoid/NNP)
#   foods/NNS
#   and/CC
#   beverages/NNS
#   from/IN
#   (CHUNK street/NN)
#   vendors/NNS
#   ./.)
# (S
#   It/PRP
#   is/VBZ
#   difficult/JJ
#   for/IN
#   (CHUNK food/NN)
#   to/TO
#   be/VB
#   kept/VBN
#   clean/JJ
#   on/IN
#   (CHUNK the/DT street/NN)
#   ,/,
#   and/CC
#   many/JJ
#   travelers/NNS
#   get/VBP
#   sick/JJ
#   from/IN
#   (CHUNK food/NN)
#   bought/VBN
#   from/IN
#   (CHUNK street/NN)
#   vendors/NNS
#   ./.)
# (S
#   (CHUNK Pangasinan/NNP)
#   (CHUNK health/NN)
#   authorities/NNS
#   on/IN
#   (CHUNK Tuesday/NNP)
#   reminded/VBD
#   (CHUNK the/DT public/NN)
#   to/TO
#   be/VB
#   careful/JJ
#   of/IN
#   (CHUNK the/DT food/NN)
#   they/PRP
#   buy/VBP
#   ,/,
#   especially/RB
#   from/IN
#   ambulant/JJ
#   vendors/NNS
#   ,/,
#   as/IN
#   (CHUNK gastroenteritis/NN)
#   and/CC
#   (CHUNK typhoid/NN)
#   (CHUNK fever/NN)
#   cases/NNS
#   were/VBD
#   on/IN
#   (CHUNK the/DT rise/NN)
#   in/IN
#   (CHUNK the/DT province/NN)
#   during/IN
#   the/DT
#   first/JJ
#   five/CD
#   months/NNS
#   of/IN
#   2015/CD
#   ./.)
# (S
#   According/VBG
#   to/TO
#   (CHUNK a/DT report/NN)
#   from/IN
#   (CHUNK GMA/NNP Dagupan/NNP)
#   ,/,
#   the/DT
#   (CHUNK Provincial/NNP Health/NNP Office/NNP)
#   (/(
#   (CHUNK PHO/NNP)
#   )/)
#   found/VBD
#   that/IN
#   from/IN
#   (CHUNK January/NNP)
#   1/CD
#   to/TO
#   (CHUNK June/NNP)
#   1/CD
#   ,/,
#   there/EX
#   were/VBD
#   261/CD
#   cases/NNS
#   of/IN
#   (CHUNK typhoid/NN)
#   (CHUNK fever/NN)
#   compared/VBN
#   to/TO
#   230/CD
#   during/IN
#   (CHUNK the/DT same/JJ period/NN)
#   (CHUNK last/JJ year/NN)
#   ./.)
# (S
#   There/EX
#   were/VBD
#   also/RB
#   4,100/CD
#   cases/NNS
#   of/IN
#   (CHUNK gastroenteritis/NN)
#   from/IN
#   (CHUNK January/NNP)
#   1/CD
#   to/TO
#   (CHUNK June/NNP)
#   1/CD
#   ,/,
#   compared/VBN
#   to/TO
#   3,900/CD
#   (CHUNK last/JJ year/NN)
#   ./.)
# (S
#   The/DT
#   (CHUNK Pangasinan/NNP)
#   (CHUNK provincial/JJ health/NN)
#   (CHUNK officer/NN)
#   (CHUNK Dr./NNP Anna/NNP)
#   de/IN
#   (CHUNK Guzman/NNP)
#   warned/VBD
#   that/IN
#   the/DT
#   illnesses/NNS
#   came/VBD
#   from/IN
#   (CHUNK the/DT contaminated/JJ water/NN)
#   and/CC
#   mishandled/VBD
#   (CHUNK food/NN)
#   ./.)
# (S
#   Also/RB
#   ,/,
#   (CHUNK food/NN)
#   can/MD
#   spoil/VB
#   quickly/RB
#   and/CC
#   is/VBZ
#   susceptible/JJ
#   to/TO
#   (CHUNK contamination/NN)
#   ,/,
#   especially/RB
#   during/IN
#   hot/JJ
#   and/CC
#   humid/JJ
#   periods/NNS
#   To/TO
#   prevent/VB
#   more/JJR
#   illnesses/NNS
#   ,/,
#   vendors/NNS
#   applying/VBG
#   for/IN
#   (CHUNK a/DT sanitary/JJ permit/NN)
#   to/TO
#   operate/VB
#   were/VBD
#   given/VBN
#   lessons/NNS
#   on/IN
#   (CHUNK proper/JJ food/NN)
#   (CHUNK handling/NN)
#   by/IN
#   the/DT
#   (CHUNK PHO/NNP)
#   ./.)
# (S
#   ``/``
#   (CHUNK Nagsasagawa/NNP)
#   (CHUNK kami/NN)
#   (CHUNK ng/JJ orientation/NN)
#   (CHUNK sa/NN)
#   (CHUNK mga/NN)
#   (CHUNK tindera/NN)
#   na/TO
#   (CHUNK dapat/NN)
#   may/MD
#   sanitary/VB
#   (CHUNK permit/NN)
#   (CHUNK din/NN)
#   ,/,
#   ''/''
#   de/IN
#   (CHUNK Guzman/NNP)
#   said/VBD
#   ./.)
# (S
#   According/VBG
#   to/TO
#   the/DT
#   (CHUNK MedlinePlus/NNP)
#   (CHUNK website/NN)
#   ,/,
#   (CHUNK typhoid/JJ fever/NN)
#   is/VBZ
#   (CHUNK an/DT infection/NN)
#   that/WDT
#   causes/VBZ
#   (CHUNK diarrhea/NN)
#   and/CC
#   (CHUNK a/DT rash/NN)
#   commonly/RB
#   caused/VBN
#   by/IN
#   (CHUNK the/DT bacterium/NN)
#   (CHUNK Salmonella/NNP)
#   (CHUNK typhi/NN)
#   ./.)
# (S
#   (CHUNK Symptoms/NNP)
#   include/VBP
#   (CHUNK fever/NN)
#   ,/,
#   (CHUNK general/JJ ill-feeling/NN)
#   and/CC
#   (CHUNK abdominal/JJ pain/NN)
#   ,/,
#   as/RB
#   well/RB
#   as/IN
#   (CHUNK high/JJ fever/NN)
#   (/(
#   39.5/CD
#   degrees/NNS
#   (CHUNK Celsius/NNP)
#   )/)
#   or/CC
#   higher/JJR
#   and/CC
#   (CHUNK severe/JJ diarrhea/NN)
#   ./.)
# (S
#   (CHUNK Medline/NNP)
#   described/VBD
#   gastroenteritis/SYM
#   -/:
#   also/RB
#   called/VBD
#   (CHUNK stomach/NN)
#   (CHUNK flu/NN)
#   -/:
#   as/IN
#   (CHUNK an/DT inflammation/NN)
#   of/IN
#   (CHUNK the/DT lining/NN)
#   of/IN
#   the/DT
#   intestines/NNS
#   caused/VBN
#   by/IN
#   (CHUNK a/DT virus/NN)
#   ,/,
#   bacteria/NNS
#   or/CC
#   parasites/NNS
#   ./.)
# (S
#   (CHUNK Symptoms/NNP)
#   include/VBP
#   (CHUNK diarrhea/NN)
#   ,/,
#   (CHUNK abdominal/JJ pain/NN)
#   ,/,
#   (CHUNK vomiting/NN)
#   ,/,
#   (CHUNK headache/NN)
#   ,/,
#   (CHUNK fever/NN)
#   and/CC
#   chills/NNS
#   ,/,
#   though/IN
#   most/JJS
#   may/MD
#   recover/VB
#   with/IN
#   (CHUNK no/DT treatment/NN)
#   ./.)
# (S
#   But/CC
#   (CHUNK gastroenteritis/NN)
#   '/''
#   most/RBS
#   (CHUNK common/JJ problem/NN)
#   is/VBZ
#   (CHUNK dehydration/NN)
#   ,/,
#   especially/RB
#   in/IN
#   infants/NNS
#   ,/,
#   young/JJ
#   children/NNS
#   ,/,
#   elderly/JJ
#   and/CC
#   people/NNS
#   with/IN
#   weak/JJ
#   immune/JJ
#   systems/NNS
#   ./.)
# (S
#   (CHUNK MANILA/NNP)
#   ,/,
#   (CHUNK Philippines/NNP)
#   -/:
#   More/JJR
#   than/IN
#   500/CD
#   residents/NNS
#   in/IN
#   18/CD
#   villages/NNS
#   in/IN
#   (CHUNK Calamba/NNP City/NNP)
#   in/IN
#   (CHUNK Laguna/NNP)
#   were/VBD
#   hospitalized/VBN
#   due/JJ
#   to/TO
#   typhoid/VB
#   (CHUNK fever/NN)
#   ,/,
#   (CHUNK GMA/NNP)
#   's/POS
#   (CHUNK Unang/NNP Balita/NNP)
#   reported/VBD
#   (CHUNK Monday/NNP)
#   ./.)
# (S
#   (CHUNK The/DT television/NN)
#   (CHUNK report/NN)
#   said/VBD
#   severely/RB
#   affected/VBN
#   were/VBD
#   villages/NNS
#   (CHUNK Pansol/NNP)
#   and/CC
#   (CHUNK Bucal/NNP)
#   ./.)
# (S
#   Based/VBN
#   on/IN
#   (CHUNK the/DT record/NN)
#   of/IN
#   (CHUNK Philippine/NNP National/NNP Red/NNP Cross/NNP)
#   ,/,
#   504/CD
#   patients/NNS
#   were/VBD
#   being/VBG
#   treated/VBN
#   in/IN
#   nine/CD
#   hospitals/NNS
#   in/IN
#   (CHUNK the/DT city/NN)
#   as/IN
#   of/IN
#   10/CD
#   (CHUNK p.m./NN)
#   (CHUNK Sunday/NNP)
#   ./.)
# (S
#   The/DT
#   (CHUNK PNRC-Laguna/NNP)
#   (CHUNK chapter/NN)
#   said/VBD
#   patients/NNS
#   downed/VBN
#   by/IN
#   (CHUNK typhoid/NN)
#   (CHUNK fever/NN)
#   started/VBD
#   pouring/VBG
#   into/IN
#   hospitals/NNS
#   (CHUNK February/NNP)
#   16/CD
#   ./.)
# (S
#   (CHUNK The/DT number/NN)
#   of/IN
#   patients/NNS
#   doubled/VBN
#   (CHUNK last/JJ week/NN)
#   ./.)
# (S
#   ``/``
#   (CHUNK Sa/NNP)
#   (CHUNK ganitong/NN)
#   (CHUNK karaming/NN)
#   cases/NNS
#   ,/,
#   (CHUNK sa/JJ tingin/NN)
#   (CHUNK po/NN)
#   (CHUNK namin/NN)
#   (CHUNK mukhang/NN)
#   (CHUNK water/NN)
#   (CHUNK ang/NN)
#   (CHUNK pinagmulan/NN)
#   (/(
#   (CHUNK ng/JJ sakit/NN)
#   )/)
#   ,/,
#   ''/''
#   (CHUNK Dr./NNP Chari/NNP Juangco/NNP)
#   ,/,
#   (CHUNK JP/NNP Rizal/NNP Memorial/NNP Medical/NNP Center/NNP)
#   ,/,
#   told/VBD
#   (CHUNK GMA/NNP News/NNP)
#   ./.)
# (S
#   At/IN
#   least/JJS
#   157/CD
#   typhoid/JJ
#   patients/NNS
#   were/VBD
#   being/VBG
#   treated/VBN
#   at/IN
#   the/DT
#   said/VBD
#   (CHUNK hospital/NN)
#   which/WDT
#   only/RB
#   has/VBZ
#   (CHUNK a/DT capacity/NN)
#   to/TO
#   accommodate/VB
#   50/CD
#   patients/NNS
#   at/IN
#   (CHUNK a/DT time/NN)
#   ./.)
# (S
#   (CHUNK The/DT television/NN)
#   (CHUNK report/NN)
#   said/VBD
#   most/JJS
#   of/IN
#   the/DT
#   patients/NNS
#   at/IN
#   (CHUNK JP/NNP Rizal/NNP Memorial/NNP Medical/NNP Center/NNP)
#   were/VBD
#   on/IN
#   (CHUNK the/DT floor/NN)
#   due/JJ
#   to/TO
#   (CHUNK the/DT hospital/NN)
#   's/POS
#   (CHUNK insufficient/JJ number/NN)
#   of/IN
#   beds/NNS
#   ./.)
# (S
#   (CHUNK Juangco/NNP)
#   said/VBD
#   they/PRP
#   are/VBP
#   also/RB
#   having/VBG
#   (CHUNK a/DT shortage/NN)
#   of/IN
#   medicines/NNS
#   and/CC
#   medical/JJ
#   supplies/NNS
#   ./.)
# (S
#   ``/``
#   'Yung/CD
#   (CHUNK IV/NNP)
#   (/(
#   intravenous/JJ
#   )/)
#   lines/NNS
#   po/VBP
#   (CHUNK namin/JJ talagang/NN)
#   (CHUNK nauubusan/JJ po/NN)
#   (CHUNK kami/NN)
#   ,/,
#   (CHUNK yung/NN)
#   (CHUNK suwero/NN)
#   ,/,
#   (CHUNK IV/NNP)
#   (CHUNK fluid/NN)
#   ,/,
#   (CHUNK yung/NN)
#   (CHUNK ibang/NN)
#   medications/NNS
#   po/VBP
#   (CHUNK namin/JJ medyo/NN)
#   (CHUNK nagkakaubusan/NN)
#   ,/,
#   ''/''
#   she/PRP
#   said/VBD
#   ./.)
# (S
#   (CHUNK The/DT television/NN)
#   (CHUNK report/NN)
#   said/VBD
#   (CHUNK Department/NNP)
#   of/IN
#   (CHUNK Health-Region/NNP)
#   4/CD
#   is/VBZ
#   now/RB
#   conducting/VBG
#   (CHUNK test/NN)
#   on/IN
#   (CHUNK the/DT water/NN)
#   (CHUNK sample/NN)
#   from/IN
#   the/DT
#   (CHUNK Calamba/NNP Water/NNP District/NNP)
#   ./.)

# %%
from nltk.corpus import conll2000
test_sents = conll2000.chunked_sents('test.txt', chunk_types=['NP'])
grammar = r"NP: {<[CDJNP].*>+}"
cp = nltk.RegexpParser(grammar)
print(cp.evaluate(test_sents))
# Out:
# ChunkParse score:
#     IOB Accuracy:  87.7%%
#     Precision:     70.6%%
#     Recall:        67.8%%
#     F-Measure:     69.2%%

# %%
from nltk.corpus import conll2000
test_sents = conll2000.chunked_sents('test.txt', chunk_types=['NP'])
train_sents = conll2000.chunked_sents('train.txt', chunk_types=['NP'])

class UnigramChunker(nltk.ChunkParserI):
    def __init__(self, train_sents): [1]
        train_data = [[(t,c) for w,t,c in nltk.chunk.tree2conlltags(sent)]
                      for sent in train_sents]
        self.tagger = nltk.UnigramTagger(train_data) [2]

    def parse(self, sentence): [3]
        pos_tags = [pos for (word,pos) in sentence]
        tagged_pos_tags = self.tagger.tag(pos_tags)
        chunktags = [chunktag for (pos, chunktag) in tagged_pos_tags]
        conlltags = [(word, pos, chunktag) for ((word,pos),chunktag)
                     in zip(sentence, chunktags)]
        return nltk.chunk.conlltags2tree(conlltags)
    
unigram_chunker = UnigramChunker(train_sents)
print(unigram_chunker.evaluate(test_sents))
