# %%
import os, json, collections
import numpy as np
import pandas as pd
import matplotlib as plt
from nltk import *
from nltk.chunk import *
from nltk.stem import *
# %matplotlib inline

# %%
df = pd.read_json('semantics.json')
text = df['content'][0]
sents = nltk.word_tokenize(text)
words = nltk.pos_tag(sents)
words
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7b1f8353317b> in <module>()
#       1 df = pd.read_json('semantics.json')
#       2 text = df['content'][0]
# ----> 3 sents = nltk.word_tokenize(text)
#       4 words = nltk.pos_tag(sents)
#       5 words
#
# NameError: name 'nltk' is not defined

# %%
tree = nltk.ne_chunk(words, binary=True)
iob = nltk.chunk.tree2conlltags(tree)
iob
# Out:
# [('ISABELA', 'NNP', 'B-NE'),
#  (',', ',', 'O'),
#  ('Philippines', 'NNP', 'B-NE'),
#  ('–', 'VBZ', 'O'),
#  ('The', 'DT', 'O'),
#  ('rainy', 'NN', 'O'),
#  ('season', 'NN', 'O'),
#  ('has', 'VBZ', 'O'),
#  ('just', 'RB', 'O'),
#  ('started', 'VBN', 'O'),
#  (',', ',', 'O'),
#  ('but', 'CC', 'O'),
#  ('the', 'DT', 'O'),
#  ('municipality', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('Luna', 'NNP', 'B-NE'),
#  ('in', 'IN', 'O'),
#  ('Isabela', 'NNP', 'B-NE'),
#  ('province', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('northern', 'JJ', 'O'),
#  ('Philippines', 'NNPS', 'O'),
#  ('already', 'RB', 'O'),
#  ('declared', 'VBD', 'O'),
#  ('state', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('calamity', 'NN', 'O'),
#  ('after', 'IN', 'O'),
#  ('their', 'PRP$', 'O'),
#  ('health', 'NN', 'O'),
#  ('office', 'NN', 'O'),
#  ('recorded', 'VBD', 'O'),
#  ('54', 'CD', 'O'),
#  ('cases', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('dengue', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('just', 'RB', 'O'),
#  ('the', 'DT', 'O'),
#  ('month', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('June', 'NNP', 'O'),
#  ('.', '.', 'O'),
#  ('Dengue', 'NNP', 'B-NE'),
#  ('is', 'VBZ', 'O'),
#  ('a', 'DT', 'O'),
#  ('fever', 'NN', 'O'),
#  (',', ',', 'O'),
#  ('usually', 'RB', 'O'),
#  ('fatal', 'JJ', 'O'),
#  (',', ',', 'O'),
#  ('caused', 'VBN', 'O'),
#  ('by', 'IN', 'O'),
#  ('a', 'DT', 'O'),
#  ('bite', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('Aedes', 'NNP', 'B-NE'),
#  ('mosquito', 'NN', 'O'),
#  ('.', '.', 'O'),
#  ('It', 'PRP', 'O'),
#  ('targets', 'VBZ', 'O'),
#  ('the', 'DT', 'O'),
#  ('immune', 'JJ', 'O'),
#  ('system', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('body', 'NN', 'O'),
#  ('.', '.', 'O'),
#  ('Dr', 'NNP', 'O'),
#  ('Claire', 'NNP', 'O'),
#  ('Francisco', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('Luna', 'NNP', 'B-NE'),
#  ('’', 'NNP', 'O'),
#  ('s', 'VBZ', 'O'),
#  ('health', 'NN', 'O'),
#  ('officer', 'NN', 'O'),
#  (',', ',', 'O'),
#  ('said', 'VBD', 'O'),
#  ('on', 'IN', 'O'),
#  ('Tuesday', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('June', 'NNP', 'O'),
#  ('30', 'CD', 'O'),
#  (',', ',', 'O'),
#  ('the', 'DT', 'O'),
#  ('number', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('cases', 'NNS', 'O'),
#  ('reported', 'VBN', 'O'),
#  ('for', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('month', 'NN', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('“', 'RBR', 'O'),
#  ('significantly', 'RB', 'O'),
#  ("''", "''", 'O'),
#  ('higher', 'JJR', 'O'),
#  ('compared', 'VBN', 'O'),
#  ('to', 'TO', 'O'),
#  ('the', 'DT', 'O'),
#  ('numbers', 'NNS', 'O'),
#  ('reported', 'VBN', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('same', 'JJ', 'O'),
#  ('month', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('previous', 'JJ', 'O'),
#  ('years', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('Although', 'IN', 'O'),
#  ('there', 'EX', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('no', 'DT', 'O'),
#  ('case', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('death', 'NN', 'O'),
#  ('from', 'IN', 'O'),
#  ('dengue', 'NN', 'O'),
#  ('yet', 'RB', 'O'),
#  (',', ',', 'O'),
#  ('the', 'DT', 'O'),
#  ('increase', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('reported', 'JJ', 'O'),
#  ('cases', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('disease', 'NN', 'O'),
#  ('prompted', 'VBD', 'O'),
#  ('the', 'DT', 'O'),
#  ('local', 'JJ', 'O'),
#  ('government', 'NN', 'O'),
#  ('unit', 'NN', 'O'),
#  ('to', 'TO', 'O'),
#  ('declare', 'VB', 'O'),
#  ('a', 'DT', 'O'),
#  ('state', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('calamity', 'NN', 'O'),
#  ('to', 'TO', 'O'),
#  ('be', 'VB', 'O'),
#  ('able', 'JJ', 'O'),
#  ('to', 'TO', 'O'),
#  ('release', 'VB', 'O'),
#  ('funds', 'NNS', 'O'),
#  ('for', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('purchase', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('medical', 'JJ', 'O'),
#  ('equipment', 'NN', 'O'),
#  ('.', '.', 'O'),
#  ('Francisco', 'NNP', 'B-NE'),
#  ('said', 'VBD', 'O'),
#  ('the', 'DT', 'O'),
#  ('purchase', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('equipment', 'NN', 'O'),
#  ('will', 'MD', 'O'),
#  ('also', 'RB', 'O'),
#  ('be', 'VB', 'O'),
#  ('anticipation', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('more', 'JJR', 'O'),
#  ('cases', 'NNS', 'O'),
#  ('during', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('rainy', 'NN', 'O'),
#  ('season', 'NN', 'O'),
#  ('.', '.', 'O'),
#  ('Thirteen', 'VB', 'O'),
#  ('out', 'IN', 'O'),
#  ('of', 'IN', 'O'),
#  ('19', 'CD', 'O'),
#  ('barangays', 'NNS', 'O'),
#  ('(', '(', 'O'),
#  ('villages', 'NNS', 'O'),
#  (')', ')', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('town', 'NN', 'O'),
#  ('were', 'VBD', 'O'),
#  ('affected', 'VBN', 'O'),
#  (',', ',', 'O'),
#  ('she', 'PRP', 'O'),
#  ('said', 'VBD', 'O'),
#  ('.', '.', 'O'),
#  ('Francisco', 'NNP', 'B-NE'),
#  ('advised', 'VBD', 'O'),
#  ('residents', 'NNS', 'O'),
#  ('to', 'TO', 'O'),
#  ('maintain', 'VB', 'O'),
#  ('cleanliness', 'NN', 'O'),
#  ('and', 'CC', 'O'),
#  ('get', 'VB', 'O'),
#  ('rid', 'JJ', 'O'),
#  ('of', 'IN', 'O'),
#  ('stagnant', 'JJ', 'O'),
#  ('waters', 'NNS', 'O'),
#  ('so', 'RB', 'O'),
#  ('dengue-causing', 'JJ', 'O'),
#  ('mosquitoes', 'NNS', 'O'),
#  ('would', 'MD', 'O'),
#  ('not', 'RB', 'O'),
#  ('have', 'VB', 'O'),
#  ('places', 'NNS', 'O'),
#  ('to', 'TO', 'O'),
#  ('breed', 'VB', 'O'),
#  ('in', 'IN', 'O'),
#  ('.', '.', 'O'),
#  ('Riseing', 'VBG', 'O'),
#  ('cases', 'NNS', 'O'),
#  ('In', 'IN', 'O'),
#  ('April', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('the', 'DT', 'O'),
#  ('Department', 'NNP', 'O'),
#  ('of', 'IN', 'O'),
#  ('Health', 'NNP', 'B-NE'),
#  ('(', '(', 'O'),
#  ('DOH', 'NNP', 'B-NE'),
#  (')', ')', 'O'),
#  ('reported', 'VBD', 'O'),
#  ('6.49', 'CD', 'O'),
#  ('%', 'NN', 'O'),
#  ('increase', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('dengue', 'JJ', 'O'),
#  ('cases', 'NNS', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('country', 'NN', 'O'),
#  (',', ',', 'O'),
#  ('citing', 'VBG', 'O'),
#  ('19,946', 'CD', 'O'),
#  ('cases', 'NNS', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('first', 'JJ', 'O'),
#  ('quarter', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('2015', 'CD', 'O'),
#  ('.', '.', 'O'),
#  ('The', 'DT', 'O'),
#  ('number', 'NN', 'O'),
#  ('reached', 'VBD', 'O'),
#  ('744', 'CD', 'O'),
#  ('in', 'IN', 'O'),
#  ('Cagayan', 'NNP', 'B-NE'),
#  ('Valley', 'NNP', 'I-NE'),
#  (',', ',', 'O'),
#  ('while', 'IN', 'O'),
#  ('Calabarzon', 'NNP', 'B-NE'),
#  ('had', 'VBD', 'O'),
#  ('the', 'DT', 'O'),
#  ('highest', 'JJS', 'O'),
#  ('with', 'IN', 'O'),
#  ('3,778', 'CD', 'O'),
#  ('and', 'CC', 'O'),
#  ('the', 'DT', 'O'),
#  ('Autonomous', 'JJ', 'B-NE'),
#  ('Region', 'NNP', 'I-NE'),
#  ('of', 'IN', 'O'),
#  ('Muslim', 'NNP', 'B-NE'),
#  ('Mindanao', 'NNP', 'I-NE'),
#  ('(', '(', 'O'),
#  ('ARMM', 'NNP', 'B-NE'),
#  (')', ')', 'O'),
#  ('had', 'VBD', 'O'),
#  ('the', 'DT', 'O'),
#  ('lowest', 'JJS', 'O'),
#  ('with', 'IN', 'O'),
#  ('312', 'CD', 'O'),
#  ('.', '.', 'O'),
#  ('Philhealth', 'NN', 'O'),
#  ('subsidizes', 'VBZ', 'O'),
#  ('dengue', 'JJ', 'O'),
#  ('case', 'NN', 'O'),
#  ('confinement', 'NN', 'O'),
#  ('with', 'IN', 'O'),
#  ('to', 'TO', 'O'),
#  ('P31,300', 'NNP', 'O'),
#  ('for', 'IN', 'O'),
#  ('level', 'NN', 'O'),
#  ('3', 'CD', 'O'),
#  ('.', '.', 'O'),
#  ('The', 'DT', 'O'),
#  ('subsidy', 'NN', 'O'),
#  ('covers', 'VBZ', 'O'),
#  ('the', 'DT', 'O'),
#  ('maximum', 'JJ', 'O'),
#  ('allowable', 'JJ', 'O'),
#  ('expense', 'NN', 'O'),
#  ('for', 'IN', 'O'),
#  ('room', 'NN', 'O'),
#  (',', ',', 'O'),
#  ('drugs', 'NNS', 'O'),
#  ('and', 'CC', 'O'),
#  ('medicines', 'NNS', 'O'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('laboratory', 'NN', 'O'),
#  ('tests', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('The', 'DT', 'O'),
#  ('health', 'NN', 'O'),
#  ('department', 'NN', 'O'),
#  ('is', 'VBZ', 'O'),
#  ('expecting', 'VBG', 'O'),
#  ('the', 'DT', 'O'),
#  ('number', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('dengue', 'JJ', 'O'),
#  ('cases', 'NNS', 'O'),
#  ('to', 'TO', 'O'),
#  ('peak', 'VB', 'O'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('months', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('July', 'NNP', 'O'),
#  ('and', 'CC', 'O'),
#  ('August', 'NNP', 'O'),
#  ('.', '.', 'O')]
